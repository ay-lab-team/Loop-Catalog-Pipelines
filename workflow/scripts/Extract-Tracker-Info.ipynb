# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/mnt/BioAdHoc/Groups/vd-ay/nrao/hichip_database/hichip-db-loop-calling/workflow/scripts'

# %%
df = pd.read_csv('../../results/samplesheets/hicpro/2022.03.18.HiChIP_Tracker.tsv', sep='\t', header=1)
df.head()
# Out:
#   Sample Name (as used in the server)                 Study     GSE ID  \
# 0                       mES_25m_cells  Mumbach et al., 2017  GSE101498
# 1                       mES_25m_cells  Mumbach et al., 2017  GSE101498
# 2                       mES_25m_cells  Mumbach et al., 2017  GSE101498
# 3                       mES_25m_cells  Mumbach et al., 2017  GSE101498
# 4                      mES_500k_cells  Mumbach et al., 2017  GSE101498
#
#        GSM ID      SRR ID                                          GEO Title  \
# 0  GSM2705031  SRR5831479  mES HiChIP H3K27ac 25m biological replicate 1 ...
# 1  GSM2705032  SRR5831480  mES HiChIP H3K27ac 25m biological replicate 1 ...
# 2  GSM2705033  SRR5831481  mES HiChIP H3K27ac 25m biological replicate 2 ...
# 3  GSM2705034  SRR5831482  mES HiChIP H3K27ac 25m biological replicate 2 ...
# 4  GSM2705035  SRR5831483     mES HiChIP H3K27ac 500k biological replicate 1
#
#                       GEO Source  \
# 0  v6.5 embryonic stem cell line
# ...

# %%
df.columns
# Out:
# Index(['Sample Name (as used in the server)', 'Study', 'GSE ID', 'GSM ID',
#        'SRR ID', 'GEO Title', 'GEO Source', 'GEO Description', 'Organism',
#        'Number of Reads', 'Biological Replicate Serial No',
#        'Technical Replicate Serial No', 'ChIP-seq Pull Down',
#        'Restriction Enzyme', 'HiCPro Status', 'HiChIP Peaks Status',
#        'hichipper Status', ' OTHER Status', 'FitHiChIP Status', 'Operator',
#        'Priority', 'Cluster Path/Branch', 'Comments'],
#       dtype='object')

# %%
df['Sample Name (as used in the server)'] +
