# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
from IPython.display import display
import time 
import tracker
latest_date = tracker.processing_dates[-1]
os.chdir('/mnt/BioAdHoc/Groups/vd-ay/kfetter/hichip-db-loop-calling/')
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('max_colwidth', 400)

# %%
latest_date
# Out:
# '2022.07.03.17.47'

# %%
# setting input and output with jupyter notebook in context 
if 'ipykernel_launcher.py' in sys.argv[0]:
    input_fn = 'results/samplesheets/hicpro/{}.hicpro.samplesheet.with_header.tsv'.format(latest_date)
    output_prefix = 'results/samplesheets/hicpro/{}.hicpro.post-check.split_fastqs'.format(latest_date)
else:
    input_fn = sys.argv[1]
    output_fn = sys.argv[2]

# %% [markdown]
# ## Helper Functions

# %%
def read_log(log):
    
    status = 0
    sample_name = 'check'
    gse_id = 'check'
    date = ''

    # extract job_id and index
    meta = os.path.basename(log)
    meta = meta.split('.')[1].split('-')
    job_id = meta[0].replace('o', '')
    index = meta[1]

    with open(log, errors='ignore') as fr:
        for line in fr:
            info = line.strip()
            if 'sample_name' in info:
                sample_name = info.split()[1]
            elif 'geo_id' in info:
                gse_id = info.split()[1]
            elif 'Ended: split_fastqs' in info:
                status = 1

    return([index, sample_name, gse_id, job_id, status])

# %% [markdown]
# ## Check Logs

# %%
# load the data
df = pd.read_table(input_fn)
df['sample_index'] = df.index + 1 # add 1 since we'll be using 1-based indexing with sed

# %%
df
# Out:
#                                                    std_sample_name     gse_id  \
# 0                        A673_SA1m1.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 1                        A673_SA1m1.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 2                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 3                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 4                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b3  GSE133227
# 5                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b4  GSE133227
# 6                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b5  GSE133227
# 7                     A673_SA2m1.GSE133227.Homo_Sapiens.H3K27ac.b1  GSE133227
# 8                     A673_SA2m1.GSE133227.Homo_Sapiens.H3K27ac.b2  GSE133227
# 9                     A673_SA2m1.GSE133227.Homo_Sapiens.H3K27ac.b3  GSE133227
# 10                        A673_SA2r.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 11                        A673_SA2r.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 12                        A673_SA2r.GSE133227.Homo_Sapiens.CTCF.b3  GSE133227
# 13                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b1  GSE133227
# 14                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b2  GSE133227
# 15                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b3  GSE133227
# 16                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b4  GSE133227
# 17                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b5  GSE133227
# 18                          A673_WT.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 61          THP-1-del-TRP-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b2  GSE149420
# 62                  THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 63                      THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 64                THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 65                  THP-1-eIFIDR.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 66                 THP-1-del-TRP.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 67               PAEC-siRNA-Ctrl.GSE152900.Homo_Sapiens.H3K27ac.b1  GSE152900
# 68               PAEC-siRNA-Ctrl.GSE152900.Homo_Sapiens.H3K27ac.b2  GSE152900
# 69             PAEC-siRNA-KLF2-4.GSE152900.Homo_Sapiens.H3K27ac.b1  GSE152900
# 70             PAEC-siRNA-KLF2-4.GSE152900.Homo_Sapiens.H3K27ac.b2  GSE152900
# 71                       KYSE180.GSE155184.Homo_Sapiens.H3K27ac.b1  GSE155184
# 72   cbCD34+-HSPC-SJALL068279-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 73   cbCD34+-HSPC-SJAUL068292-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 74  cbCD34+-HSPC-SJMPAL011914-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 75  cbCD34+-HSPC-SJTALL005006-D2.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 76  cbCD34+-HSPC-SJMPAL011911-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 77                         DND41.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 78                         DND41.GSE165207.Homo_Sapiens.H3K27ac.b2  GSE165207
# 79                        Jurkat.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 80              CD34+-Cord-Blood.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 81                          GM12878.GSE80820.Homo_Sapiens.SMC1A.b1   GSE80820
# 82                          GM12878.GSE80820.Homo_Sapiens.SMC1A.b2   GSE80820
#
#         organism  bio_rep antibody_target  restriction_enzyme  \
# 0   Homo_Sapiens        1            CTCF                MboI
# 1   Homo_Sapiens        2            CTCF                MboI
# 2   Homo_Sapiens        1            CTCF                MboI
# 3   Homo_Sapiens        2            CTCF                MboI
# 4   Homo_Sapiens        3            CTCF                MboI
# 5   Homo_Sapiens        4            CTCF                MboI
# 6   Homo_Sapiens        5            CTCF                MboI
# 7   Homo_Sapiens        1         H3K27ac                MboI
# 8   Homo_Sapiens        2         H3K27ac                MboI
# 9   Homo_Sapiens        3         H3K27ac                MboI
# 10  Homo_Sapiens        1            CTCF                MboI
# 11  Homo_Sapiens        2            CTCF                MboI
# 12  Homo_Sapiens        3            CTCF                MboI
# 13  Homo_Sapiens        1         H3K27ac                MboI
# 14  Homo_Sapiens        2         H3K27ac                MboI
# 15  Homo_Sapiens        3         H3K27ac                MboI
# 74  Homo_Sapiens        1         H3K27ac               Arima
# 75  Homo_Sapiens        1         H3K27ac               Arima
# 76  Homo_Sapiens        1         H3K27ac               Arima
# 77  Homo_Sapiens        1         H3K27ac               Arima
# 78  Homo_Sapiens        2         H3K27ac               Arima
# 79  Homo_Sapiens        1         H3K27ac               Arima
# 80  Homo_Sapiens        1         H3K27ac               Arima
# 81  Homo_Sapiens        1           SMC1A                MboI
# 82  Homo_Sapiens        2           SMC1A                MboI
#
#                      sample_name  sample_index
# 0                     A673_SA1m1             1
# 1                     A673_SA1m1             2
# 2                     A673_SA2m1             3
# 3                     A673_SA2m1             4
# 4                     A673_SA2m1             5
# 5                     A673_SA2m1             6
# 6                     A673_SA2m1             7
# 7                     A673_SA2m1             8
# 8                     A673_SA2m1             9
# 9                     A673_SA2m1            10
# 10                     A673_SA2r            11
# 11                     A673_SA2r            12
# 12                     A673_SA2r            13
# 13                     A673_SA2r            14
# 14                     A673_SA2r            15
# 15                     A673_SA2r            16
# 16                     A673_SA2r            17
# 17                     A673_SA2r            18
# 18                       A673_WT            19
# 19                       A673_WT            20
# 20                       A673_WT            21
# 21                       A673_WT            22
# 22                       A673_WT            23
# 23                       A673_WT            24
# 24                       A673_WT            25
# 25                       A673_WT            26
# 26                       A673_WT            27
# 27                    TC71_SA2m2            28
# 28                    TC71_SA2m2            29
# 29                    TC71_SA2m2            30
# 30                    TC71_SA2m2            31
# 31                       TC71_WT            32
# 32                       TC71_WT            33
# 33                       TC71_WT            34
# 34                       TC71_WT            35
# 35                       KYSE140            36
# 36                        KYSE70            37
# 37                            TT            38
# 38                           LK2            39
# 39                          H520            40
# 40                         HCC15            41
# 41                      RERFLCAI            42
# 42              KYSE140_DMSO2hrs            43
# 43               KYSE140_ARV2hrs            44
# 44                 SKMES1_sg_NC1            45
# 45                SKMES1_sg_e1_1            46
# 46                       GM12878            47
# 47                       GM12878            48
# 48                           DEX            49
# 49                           DEX            50
# 50                           CTL            51
# 51                           CTL            52
# 52                    HEC-1-B-WT            53
# 53           THP-1-Vector-Batch1            54
# 54               THP-1-WT-Batch1            55
# 55         THP-1-del-cIDR-Batch1            56
# 56       THP-1-del-eIFIDR-Batch1            57
# 57           THP-1-Vector-Batch2            58
# 58               THP-1-WT-Batch2            59
# 59         THP-1-del-cIDR-Batch2            60
# 60       THP-1-del-eIFIDR-Batch2            61
# 61          THP-1-del-TRP-Batch2            62
# 62                  THP-1-Vector            63
# 63                      THP-1-WT            64
# 64                THP-1-del-cIDR            65
# 65                  THP-1-eIFIDR            66
# 66                 THP-1-del-TRP            67
# 67               PAEC-siRNA-Ctrl            68
# 68               PAEC-siRNA-Ctrl            69
# 69             PAEC-siRNA-KLF2-4            70
# 70             PAEC-siRNA-KLF2-4            71
# 71                       KYSE180            72
# 72   cbCD34+-HSPC-SJALL068279-D1            73
# 73   cbCD34+-HSPC-SJAUL068292-D1            74
# 74  cbCD34+-HSPC-SJMPAL011914-D1            75
# 75  cbCD34+-HSPC-SJTALL005006-D2            76
# 76  cbCD34+-HSPC-SJMPAL011911-D1            77
# 77                         DND41            78
# 78                         DND41            79
# 79                        Jurkat            80
# 80              CD34+-Cord-Blood            81
# 81                       GM12878            82
# 82                       GM12878            83

# %%
print('number of samples visited:', len(df))
# Out:
# number of samples visited: 83

# %%
# create a dataframe of log information
output_logs = glob.glob('results/fastqs/parallel/logs/split_fastqs.o*-*')
log_data = []   
for out_log in output_logs:
    sample_index = out_log.split('-')[1]
    index, sample_name, gse_id, job_id, status = read_log(out_log)
    log_data.append([index, sample_name, gse_id, job_id, status, os.path.basename(out_log)])
log_df = pd.DataFrame(log_data)
log_df.columns = ['sample_index', 'std_sample_name', 'gse_id', 'job_id', 'split_status', 'log']
log_df.drop('sample_index', inplace=True, axis=1)

# %%
log_df = log_df.sort_values(by=["std_sample_name"], ascending=True).reset_index(drop=True)
log_df
# Out:
#                                                    std_sample_name     gse_id  \
# 0                        A673_SA1m1.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 1                        A673_SA1m1.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 2                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 3                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 4                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b3  GSE133227
# 5                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b4  GSE133227
# 6                        A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b5  GSE133227
# 7                     A673_SA2m1.GSE133227.Homo_Sapiens.H3K27ac.b1  GSE133227
# 8                     A673_SA2m1.GSE133227.Homo_Sapiens.H3K27ac.b2  GSE133227
# 9                     A673_SA2m1.GSE133227.Homo_Sapiens.H3K27ac.b3  GSE133227
# 10                        A673_SA2r.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 11                        A673_SA2r.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 12                        A673_SA2r.GSE133227.Homo_Sapiens.CTCF.b3  GSE133227
# 13                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b1  GSE133227
# 14                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b2  GSE133227
# 15                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b3  GSE133227
# 16                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b4  GSE133227
# 17                     A673_SA2r.GSE133227.Homo_Sapiens.H3K27ac.b5  GSE133227
# 18                          A673_WT.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 19                          A673_WT.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 20                          A673_WT.GSE133227.Homo_Sapiens.CTCF.b3  GSE133227
# 21                          A673_WT.GSE133227.Homo_Sapiens.CTCF.b4  GSE133227
# 22                          A673_WT.GSE133227.Homo_Sapiens.CTCF.b5  GSE133227
# 23                       A673_WT.GSE133227.Homo_Sapiens.H3K27ac.b1  GSE133227
# 24                       A673_WT.GSE133227.Homo_Sapiens.H3K27ac.b2  GSE133227
# 25                       A673_WT.GSE133227.Homo_Sapiens.H3K27ac.b3  GSE133227
# 26                       A673_WT.GSE133227.Homo_Sapiens.H3K27ac.b4  GSE133227
# 27              CD34+-Cord-Blood.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 28                           CTL.GSE117888.Homo_Sapiens.H3K27ac.b1  GSE117888
# 29                           CTL.GSE117888.Homo_Sapiens.H3K27ac.b2  GSE117888
# 30                           DEX.GSE117888.Homo_Sapiens.H3K27ac.b1  GSE117888
# 31                           DEX.GSE117888.Homo_Sapiens.H3K27ac.b2  GSE117888
# 32                         DND41.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 33                         DND41.GSE165207.Homo_Sapiens.H3K27ac.b2  GSE165207
# 34                          GM12878.GSE115524.Homo_Sapiens.CTCF.b1  GSE115524
# 35                          GM12878.GSE115524.Homo_Sapiens.CTCF.b2  GSE115524
# 36                          GM12878.GSE80820.Homo_Sapiens.SMC1A.b1   GSE80820
# 37                          GM12878.GSE80820.Homo_Sapiens.SMC1A.b2   GSE80820
# 38                          H520.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 39                         HCC15.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 40                         HEC-1-B-WT.GSE148958.Homo_Sapiens.V5.b1  GSE148958
# 41                        Jurkat.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 42                       KYSE140.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 43               KYSE140_ARV2hrs.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 44              KYSE140_DMSO2hrs.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 45                       KYSE180.GSE155184.Homo_Sapiens.H3K27ac.b1  GSE155184
# 46                        KYSE70.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 47                           LK2.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 48               PAEC-siRNA-Ctrl.GSE152900.Homo_Sapiens.H3K27ac.b1  GSE152900
# 49               PAEC-siRNA-Ctrl.GSE152900.Homo_Sapiens.H3K27ac.b2  GSE152900
# 50             PAEC-siRNA-KLF2-4.GSE152900.Homo_Sapiens.H3K27ac.b1  GSE152900
# 51             PAEC-siRNA-KLF2-4.GSE152900.Homo_Sapiens.H3K27ac.b2  GSE152900
# 52                      RERFLCAI.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 53                 SKMES1_sg_NC1.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 54                SKMES1_sg_e1_1.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 55                       TC71_SA2m2.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 56                       TC71_SA2m2.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 57                    TC71_SA2m2.GSE133227.Homo_Sapiens.H3K27ac.b1  GSE133227
# 58                    TC71_SA2m2.GSE133227.Homo_Sapiens.H3K27ac.b2  GSE133227
# 59                          TC71_WT.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227
# 60                          TC71_WT.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227
# 61                       TC71_WT.GSE133227.Homo_Sapiens.H3K27ac.b1  GSE133227
# 62                       TC71_WT.GSE133227.Homo_Sapiens.H3K27ac.b2  GSE133227
# 63           THP-1-Vector-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b1  GSE149420
# 64           THP-1-Vector-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b2  GSE149420
# 65                  THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 66               THP-1-WT-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b1  GSE149420
# 67               THP-1-WT-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b2  GSE149420
# 68                      THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 69          THP-1-del-TRP-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b2  GSE149420
# 70                 THP-1-del-TRP.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 71         THP-1-del-cIDR-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b1  GSE149420
# 72         THP-1-del-cIDR-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b2  GSE149420
# 73                THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 74       THP-1-del-eIFIDR-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b1  GSE149420
# 75       THP-1-del-eIFIDR-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b2  GSE149420
# 76                  THP-1-eIFIDR.GSE149420.Homo_Sapiens.H3K27ac.b1  GSE149420
# 77                            TT.GSE166232.Homo_Sapiens.H3K27ac.b1  GSE166232
# 78   cbCD34+-HSPC-SJALL068279-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 79   cbCD34+-HSPC-SJAUL068292-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 80  cbCD34+-HSPC-SJMPAL011911-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 81  cbCD34+-HSPC-SJMPAL011914-D1.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
# 82  cbCD34+-HSPC-SJTALL005006-D2.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207
#
#      job_id  split_status                       log
# 0   5038305             1   split_fastqs.o5038305-1
# 1   5038306             1   split_fastqs.o5038306-2
# 2   5038306             1   split_fastqs.o5038306-3
# 3   5038306             1   split_fastqs.o5038306-4
# 4   5038306             1   split_fastqs.o5038306-5
# 5   5038306             1   split_fastqs.o5038306-6
# 6   5038306             1   split_fastqs.o5038306-7
# 7   5038306             1   split_fastqs.o5038306-8
# 8   5038306             1   split_fastqs.o5038306-9
# 9   5038306             1  split_fastqs.o5038306-10
# 10  5038306             1  split_fastqs.o5038306-11
# 11  5038306             1  split_fastqs.o5038306-12
# 12  5038306             1  split_fastqs.o5038306-13
# 13  5038306             1  split_fastqs.o5038306-14
# 14  5038306             1  split_fastqs.o5038306-15
# 15  5038306             1  split_fastqs.o5038306-16
# 16  5038306             1  split_fastqs.o5038306-17
# 17  5038306             1  split_fastqs.o5038306-18
# 18  5038306             1  split_fastqs.o5038306-19
# 19  5038306             1  split_fastqs.o5038306-20
# 20  5038306             1  split_fastqs.o5038306-21
# 21  5038306             1  split_fastqs.o5038306-22
# 22  5038306             1  split_fastqs.o5038306-23
# 23  5038306             1  split_fastqs.o5038306-24
# 24  5038306             1  split_fastqs.o5038306-25
# 25  5038306             1  split_fastqs.o5038306-26
# 26  5038306             1  split_fastqs.o5038306-27
# 27  5038306             1  split_fastqs.o5038306-81
# 28  5038306             1  split_fastqs.o5038306-51
# 29  5038306             1  split_fastqs.o5038306-52
# 30  5038306             1  split_fastqs.o5038306-49
# 31  5038306             1  split_fastqs.o5038306-50
# 32  5038306             1  split_fastqs.o5038306-78
# 33  5038306             1  split_fastqs.o5038306-79
# 34  5038306             1  split_fastqs.o5038306-47
# 35  5038306             1  split_fastqs.o5038306-48
# 36  5038306             1  split_fastqs.o5038306-82
# 37  5038306             1  split_fastqs.o5038306-83
# 38  5038306             1  split_fastqs.o5038306-40
# 39  5038306             1  split_fastqs.o5038306-41
# 40  5038306             1  split_fastqs.o5038306-53
# 41  5038306             1  split_fastqs.o5038306-80
# 42  5038306             1  split_fastqs.o5038306-36
# 43  5038306             1  split_fastqs.o5038306-44
# 44  5038306             1  split_fastqs.o5038306-43
# 45  5038306             1  split_fastqs.o5038306-72
# 46  5038306             1  split_fastqs.o5038306-37
# 47  5038306             1  split_fastqs.o5038306-39
# 48  5038306             1  split_fastqs.o5038306-68
# 49  5038306             1  split_fastqs.o5038306-69
# 50  5038306             1  split_fastqs.o5038306-70
# 51  5038306             1  split_fastqs.o5038306-71
# 52  5038306             1  split_fastqs.o5038306-42
# 53  5038306             1  split_fastqs.o5038306-45
# 54  5038306             1  split_fastqs.o5038306-46
# 55  5038306             1  split_fastqs.o5038306-28
# 56  5038306             1  split_fastqs.o5038306-29
# 57  5038306             1  split_fastqs.o5038306-30
# 58  5038306             1  split_fastqs.o5038306-31
# 59  5038306             1  split_fastqs.o5038306-32
# 60  5038306             1  split_fastqs.o5038306-33
# 61  5038306             1  split_fastqs.o5038306-34
# 62  5038306             1  split_fastqs.o5038306-35
# 63  5038306             1  split_fastqs.o5038306-54
# 64  5038306             1  split_fastqs.o5038306-58
# 65  5038306             1  split_fastqs.o5038306-63
# 66  5038306             1  split_fastqs.o5038306-55
# 67  5038306             1  split_fastqs.o5038306-59
# 68  5038306             1  split_fastqs.o5038306-64
# 69  5038306             1  split_fastqs.o5038306-62
# 70  5038306             1  split_fastqs.o5038306-67
# 71  5038306             1  split_fastqs.o5038306-56
# 72  5038306             1  split_fastqs.o5038306-60
# 73  5038306             1  split_fastqs.o5038306-65
# 74  5038306             1  split_fastqs.o5038306-57
# 75  5038306             1  split_fastqs.o5038306-61
# 76  5038306             1  split_fastqs.o5038306-66
# 77  5038306             1  split_fastqs.o5038306-38
# 78  5038306             1  split_fastqs.o5038306-73
# 79  5038306             1  split_fastqs.o5038306-74
# 80  5038306             1  split_fastqs.o5038306-77
# 81  5038306             1  split_fastqs.o5038306-75
# 82  5038306             1  split_fastqs.o5038306-76

# %% [markdown]
# ## Identifying problem samples

# %%
problems = (log_df.split_status != 1)
problems_df = log_df.loc[problems,:]
print('nubmer of problem samples:', len(problems_df))
# Out:
# nubmer of problem samples: 0

# %%
problems_df.loc[:, ['std_sample_name', 'gse_id', 'job_id', 'split_status', 'log']]
# Out:
# Empty DataFrame
# Columns: [std_sample_name, gse_id, job_id, split_status, log]
# Index: []

# %%
header_output = '{}.with_header.tsv'.format(output_prefix)
problems_df.to_csv(header_output, header=True, index=False, sep='\t')
