# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %% [markdown]
# # Check HiC-Pro and HiCCUPS Output Files for Pairs and Loop Information

# %% [markdown]
# #### read output logs helper functions

# %%
def read_hiccups_loop_files(file):
    loop_data = {}
    count = 0
    with open(file) as fr:
        for line in fr:
            if not line.startswith('1'):
                continue
            else:
                info = line.strip().split()
                loop_info = info[0:6]
                loop_data[count] = loop_info
                count = count + 1
    return(loop_data)

# %%
def read_hicpro_stats_log(log):
    log_data = {}
    count = 0
    with open(log) as fr:
        for line in fr:
            if line.startswith('#'):
                continue
            else:
                info = line.strip().split()
                pair_info = info[0:2]
                log_data[count] = pair_info
                count = count + 1
    return(log_data)

# %% [markdown]
# #### generate data frame with loop and pairs info

# %%
loop_data = []
tpl = '/mnt/BioAdHoc/Groups/vd-ay/kfetter/hichip-db-loop-calling/results/loops/hiccups_hicpro_chr1/{sample_name}/'
glob_str = tpl.format(sample_name='*')
for fn in glob.glob(glob_str):
    sample_name = fn.split('/')[10]
    sample_info = []
    file_path5 = os.path.join(fn, "postprocessed_pixels_5000.bedpe")
    file_path10 = os.path.join(fn, "postprocessed_pixels_10000.bedpe")
    file_path25 = os.path.join(fn, "postprocessed_pixels_25000.bedpe")
    file_path_mpairstat = "/mnt/BioAdHoc/Groups/vd-ay/hichip-db-loop-calling/results/hicpro/" + sample_name + "/hic_results/stats/" + sample_name + "/" + sample_name + ".mpairstat"
    file_path_mergestat = "/mnt/BioAdHoc/Groups/vd-ay/hichip-db-loop-calling/results/hicpro/" + sample_name + "/hic_results/stats/" + sample_name + "/" + sample_name + "_allValidPairs.mergestat"
    sample_info.append(sample_name)
    if os.path.exists(file_path_mpairstat):
        pairs_info = read_hicpro_stats_log(file_path_mpairstat)
        sample_info.append(int(pairs_info[0][1]))
    else:
        sample_info.append("None")
    if os.path.exists(file_path_mergestat):
        pairs_info = read_hicpro_stats_log(file_path_mergestat)
        sample_info.append(int(pairs_info[0][1]))
    else:
        sample_info.append("None")
    if os.path.exists(file_path5):
        loop_info = read_hiccups_loop_files(file_path5)
        sample_info.append(len(loop_info))
    else:
        sample_info.append("None")
    if os.path.exists(file_path10):
        loop_info = read_hiccups_loop_files(file_path10)
        sample_info.append(len(loop_info))
    else:
        sample_info.append("None")
    if os.path.exists(file_path25):
        loop_info = read_hiccups_loop_files(file_path25)
        sample_info.append(len(loop_info))
    else:
        sample_info.append("None")    
    loop_data.append(sample_info)
loop_df = pd.DataFrame(loop_data)
loop_df.columns = ["Sample Name", "Total Pairs Processed", "Valid Interaction Pairs", "Number of 5kb Loops (Chr1 Only)", "Number of 10kb Loops (Chr1 Only)", "Number of 25kb Loops (Chr1 Only)"]

# %% [markdown]
# #### sort table by Sample Name

# %%
loop_df = loop_df.sort_values(by=["Sample Name"], ascending=True).reset_index(drop=True)
loop_df.index += 1
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(loop_df)
# Out:
#                                           Sample Name  Total Pairs Processed  \
# 1              293T-PDS.GSE128106.Homo_Sapiens.YY1.b1               45904302
# 2           293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1               92276625
# 3                  293T.GSE128106.Homo_Sapiens.YY1.b1              247695887
# 4             AoSMC.GSE178598.Homo_Sapiens.H3K27ac.b1              337307006
# 5               BC1.GSE136090.Homo_Sapiens.H3K27ac.b1               39569105
# 6               BC3.GSE136090.Homo_Sapiens.H3K27ac.b1               38225847
# 7             BCBL1.GSE136090.Homo_Sapiens.H3K27ac.b1               50329964
# 8   EBNA2_Neg_Ramos.GSE179755.Homo_Sapiens.H3K27ac.b1               69443381
# 9   EBNA2_Plus_Ramos.GSE179755.Homo_Sapiens.H3K27a...               73912411
# 10               GM.GSE101498.Homo_Sapiens.H3K27ac.b1              332279257
# 11               GM.GSE101498.Homo_Sapiens.H3K27ac.b2              299478736
# 12           H9-HS-KI.GSE105028.Homo_Sapiens.Rad21.b1              199983939
# 13               H9-HS.GSE105028.Homo_Sapiens.CTCF.b1               72025184
# 14            H9-HS.GSE105028.Homo_Sapiens.H3K4me1.b1              208844380
# 15               H9-HS.GSE105028.Homo_Sapiens.KLF4.b1               92095681
# 16              H9-HS.GSE105028.Homo_Sapiens.NANOG.b1               97626401
# 17               H9-HS.GSE105028.Homo_Sapiens.OCT4.b1              153966714
# 18              H9-HS.GSE105028.Homo_Sapiens.Rad21.b1              418316089
# 19       H9-siNIPBL-HS.GSE105028.Homo_Sapiens.CTCF.b1               56100419
# 20    H9-siNIPBL-HS.GSE105028.Homo_Sapiens.H3K4me1.b1               74434067
# 21                  H9.GSE105028.Homo_Sapiens.CTCF.b1               76803406
# 22               H9.GSE105028.Homo_Sapiens.H3K4me1.b1              135868209
# 23                  H9.GSE105028.Homo_Sapiens.KLF4.b1              130814263
# 24                 H9.GSE105028.Homo_Sapiens.NANOG.b1              104440150
# 25                  H9.GSE105028.Homo_Sapiens.OCT4.b1              130955376
# 26                 H9.GSE105028.Homo_Sapiens.Rad21.b1              515530130
# 27             HAEC.GSE178598.Homo_Sapiens.H3K27ac.b1              334543061
# 28             HARA.GSE147854.Homo_Sapiens.H3K27ac.b1               48550865
# 29            HAVIC.GSE154512.Homo_Sapiens.H3K27ac.b1              691966559
# 30           HCASMC.GSE101498.Homo_Sapiens.H3K27ac.b1              722202094
# 31           HCT116.GSE173699.Homo_Sapiens.H3K27ac.b1               89955822
# 32               HCT116.GSE92881.Homo_Sapiens.SMC1.b1               49965377
# 33             HT55.GSE147854.Homo_Sapiens.H3K27ac.b1               88687267
# 34  HaCaT_Stimulated.GSE151193.Homo_Sapiens.H3K27a...              630181138
# 35  HaCaT_Unstimulated.GSE151193.Homo_Sapiens.H3K2...              574505628
# 36              JSC.GSE136090.Homo_Sapiens.H3K27ac.b1               36734111
# 37             K562.GSE101498.Homo_Sapiens.H3K27ac.b1              213165389
# 38             K562.GSE101498.Homo_Sapiens.H3K27ac.b2              155907950
# 39             K562.GSE101498.Homo_Sapiens.H3K27ac.b3              178162951
# 40             MyLa.GSE101498.Homo_Sapiens.H3K27ac.b1              246037528
# 41             MyLa.GSE101498.Homo_Sapiens.H3K27ac.b2              212923142
# 42             MyLa.GSE151193.Homo_Sapiens.H3K27ac.b1              736804619
# 43        Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b1              364847796
# 44        Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b2              316971810
# 45     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b1               12051488
# 46     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b2              193547252
# 47     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b3              220425415
# 48            Ramos.GSE179755.Homo_Sapiens.H3K27ac.b1               42179029
# 49             Th17.GSE101498.Homo_Sapiens.H3K27ac.b1               92821305
# 50             Th17.GSE101498.Homo_Sapiens.H3K27ac.b2              204756067
# 51             Th17.GSE101498.Homo_Sapiens.H3K27ac.b3              241441720
# 52             Treg.GSE101498.Homo_Sapiens.H3K27ac.b1               31319366
# 53             Treg.GSE101498.Homo_Sapiens.H3K27ac.b2              160164015
# 54             Treg.GSE101498.Homo_Sapiens.H3K27ac.b3              316205255
# 55           lgs000379.GSE116193.Homo_Sapiens.CTCF.b1               92390968
# 56        lgs000379.GSE116193.Homo_Sapiens.H3K27ac.b1              128447244
# 57           lgs101645.GSE116193.Homo_Sapiens.CTCF.b1               50680134
# 58        lgs101645.GSE116193.Homo_Sapiens.H3K27ac.b1               41845040
# 59           lgs102580.GSE116193.Homo_Sapiens.CTCF.b1              107042962
# 60        lgs102580.GSE116193.Homo_Sapiens.H3K27ac.b1               65520972
# 61           lgs102943.GSE116193.Homo_Sapiens.CTCF.b1               35335748
# 62        lgs102943.GSE116193.Homo_Sapiens.H3K27ac.b1               35509764
# 63           lgs301283.GSE116193.Homo_Sapiens.CTCF.b1               53873305
# 64        lgs301283.GSE116193.Homo_Sapiens.H3K27ac.b1               52729360
# 65           lgs301315.GSE116193.Homo_Sapiens.CTCF.b1               39376017
# 66        lgs301315.GSE116193.Homo_Sapiens.H3K27ac.b1               39640737
#
#     Valid Interaction Pairs Number of 5kb Loops (Chr1 Only)  \
# 1                  14233750                            None
# 2                  23170231                            None
# 3                  24584547                            None
# 4                 191374595                             295
# 5                  12948113                               1
# 6                   9976222                            None
# 7                  17716612                               2
# 8                  30727420                               7
# 9                  34665842                              13
# 10                104375182                             441
# 11                 97800990                             392
# 12                 38015306                            1071
# 13                 22751546                             199
# 14                 62917771                              16
# 15                 15351518                            None
# 16                 36885673                            None
# 17                 46491751                            None
# 18                114952549                            2151
# 19                 12093604                            None
# 20                 12103970                            None
# 21                 21492716                            None
# 22                 31408907                            None
# 23                 27868879                            None
# 24                 37841966                            None
# 25                 33449237                            None
# 26                145833436                            2949
# 27                186439092                             249
# 28                 18380230                              10
# 29                151539207                              37
# 30                234954564                             337
# 31                 29690624                               1
# 32                 11375543                               2
# 33                 21215608                             178
# 34                380199595                             587
# 35                347303698                             457
# 36                 11867302                               3
# 37                 89951377                             155
# 38                 68188485                             134
# 39                 71349144                             104
# 40                 76593777                             325
# 41                 72354257                             282
# 42                445931504                             287
# 43                134702211                              69
# 44                102261615                              36
# 45                  5384572                            None
# 46                 96984223                             455
# 47                118853962                             402
# 48                 17915546                               2
# 49                 42525103                             186
# 50                105977160                             396
# 51                129610019                             329
# 52                 15083091                            None
# 53                 81322898                             256
# 54                168630830                             346
# 55                 48009927                              55
# 56                 69612885                            None
# 57                 25321243                              17
# 58                 21700174                               0
# 59                 56523486                             132
# 60                 30559861                               5
# 61                 18005883                               9
# 62                 18720816                               0
# 63                 25013643                              17
# 64                 26824960                               0
# 65                 19273695                              11
# 66                 20063791                               0
#
#    Number of 10kb Loops (Chr1 Only) Number of 25kb Loops (Chr1 Only)
# 1                              None                             None
# 2                              None                             None
# 3                              None                                0
# 4                               481                              509
# 5                                 2                                3
# 6                                 0                                1
# 7                                 8                               28
# 8                                19                               60
# 9                                32                               91
# 10                              527                              414
# 11                              498                              387
# 12                             1517                             1209
# 13                              574                              509
# 14                               49                              107
# 15                             None                                1
# 16                               10                               79
# 17                               48                               90
# 18                             2353                             None
# 19                               39                               85
# 20                             None                               36
# 21                              834                              654
# 22                               50                               90
# 23                                4                               20
# 24                               17                              107
# 25                               26                               59
# 26                             3259                             1931
# 27                              354                              317
# 28                               23                               76
# 29                              109                              290
# 30                              559                              532
# 31                                2                               40
# 32                               11                               52
# 33                              278                              232
# 34                              754                              626
# 35                              617                              519
# 36                                4                               10
# 37                              241                              248
# 38                              230                              219
# 39                              195                              219
# 40                              473                              487
# 41                              449                              463
# 42                              514                              601
# 43                              148                              228
# 44                              119                              176
# 45                             None                                6
# 46                              661                              753
# 47                              642                              766
# 48                                5                               20
# 49                              335                              399
# 50                              619                              698
# 51                              550                              646
# 52                               29                               63
# 53                              450                              558
# 54                              598                              726
# 55                              197                              370
# 56                               28                              159
# 57                               86                              248
# 58                                3                               31
# 59                              364                              550
# 60                               20                              102
# 61                               35                              142
# 62                                1                               24
# 63                               58                              189
# 64                                4                               55
# 65                               55                              166
# 66                                6                               37

# %% [markdown]
# #### sort table by Total Pairs Processed (greatest to least)

# %%
loop_df = loop_df.sort_values(by=["Total Pairs Processed"], ascending=False).reset_index(drop=True)
loop_df.index += 1
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(loop_df)
# Out:
#                                           Sample Name  Total Pairs Processed  \
# 1              MyLa.GSE151193.Homo_Sapiens.H3K27ac.b1              736804619
# 2            HCASMC.GSE101498.Homo_Sapiens.H3K27ac.b1              722202094
# 3             HAVIC.GSE154512.Homo_Sapiens.H3K27ac.b1              691966559
# 4   HaCaT_Stimulated.GSE151193.Homo_Sapiens.H3K27a...              630181138
# 5   HaCaT_Unstimulated.GSE151193.Homo_Sapiens.H3K2...              574505628
# 6                  H9.GSE105028.Homo_Sapiens.Rad21.b1              515530130
# 7               H9-HS.GSE105028.Homo_Sapiens.Rad21.b1              418316089
# 8         Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b1              364847796
# 9             AoSMC.GSE178598.Homo_Sapiens.H3K27ac.b1              337307006
# 10             HAEC.GSE178598.Homo_Sapiens.H3K27ac.b1              334543061
# 11               GM.GSE101498.Homo_Sapiens.H3K27ac.b1              332279257
# 12        Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b2              316971810
# 13             Treg.GSE101498.Homo_Sapiens.H3K27ac.b3              316205255
# 14               GM.GSE101498.Homo_Sapiens.H3K27ac.b2              299478736
# 15                 293T.GSE128106.Homo_Sapiens.YY1.b1              247695887
# 16             MyLa.GSE101498.Homo_Sapiens.H3K27ac.b1              246037528
# 17             Th17.GSE101498.Homo_Sapiens.H3K27ac.b3              241441720
# 18     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b3              220425415
# 19             K562.GSE101498.Homo_Sapiens.H3K27ac.b1              213165389
# 20             MyLa.GSE101498.Homo_Sapiens.H3K27ac.b2              212923142
# 21            H9-HS.GSE105028.Homo_Sapiens.H3K4me1.b1              208844380
# 22             Th17.GSE101498.Homo_Sapiens.H3K27ac.b2              204756067
# 23           H9-HS-KI.GSE105028.Homo_Sapiens.Rad21.b1              199983939
# 24     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b2              193547252
# 25             K562.GSE101498.Homo_Sapiens.H3K27ac.b3              178162951
# 26             Treg.GSE101498.Homo_Sapiens.H3K27ac.b2              160164015
# 27             K562.GSE101498.Homo_Sapiens.H3K27ac.b2              155907950
# 28               H9-HS.GSE105028.Homo_Sapiens.OCT4.b1              153966714
# 29               H9.GSE105028.Homo_Sapiens.H3K4me1.b1              135868209
# 30                  H9.GSE105028.Homo_Sapiens.OCT4.b1              130955376
# 31                  H9.GSE105028.Homo_Sapiens.KLF4.b1              130814263
# 32        lgs000379.GSE116193.Homo_Sapiens.H3K27ac.b1              128447244
# 33           lgs102580.GSE116193.Homo_Sapiens.CTCF.b1              107042962
# 34                 H9.GSE105028.Homo_Sapiens.NANOG.b1              104440150
# 35              H9-HS.GSE105028.Homo_Sapiens.NANOG.b1               97626401
# 36             Th17.GSE101498.Homo_Sapiens.H3K27ac.b1               92821305
# 37           lgs000379.GSE116193.Homo_Sapiens.CTCF.b1               92390968
# 38          293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1               92276625
# 39               H9-HS.GSE105028.Homo_Sapiens.KLF4.b1               92095681
# 40           HCT116.GSE173699.Homo_Sapiens.H3K27ac.b1               89955822
# 41             HT55.GSE147854.Homo_Sapiens.H3K27ac.b1               88687267
# 42                  H9.GSE105028.Homo_Sapiens.CTCF.b1               76803406
# 43    H9-siNIPBL-HS.GSE105028.Homo_Sapiens.H3K4me1.b1               74434067
# 44  EBNA2_Plus_Ramos.GSE179755.Homo_Sapiens.H3K27a...               73912411
# 45               H9-HS.GSE105028.Homo_Sapiens.CTCF.b1               72025184
# 46  EBNA2_Neg_Ramos.GSE179755.Homo_Sapiens.H3K27ac.b1               69443381
# 47        lgs102580.GSE116193.Homo_Sapiens.H3K27ac.b1               65520972
# 48       H9-siNIPBL-HS.GSE105028.Homo_Sapiens.CTCF.b1               56100419
# 49           lgs301283.GSE116193.Homo_Sapiens.CTCF.b1               53873305
# 50        lgs301283.GSE116193.Homo_Sapiens.H3K27ac.b1               52729360
# 51           lgs101645.GSE116193.Homo_Sapiens.CTCF.b1               50680134
# 52            BCBL1.GSE136090.Homo_Sapiens.H3K27ac.b1               50329964
# 53               HCT116.GSE92881.Homo_Sapiens.SMC1.b1               49965377
# 54             HARA.GSE147854.Homo_Sapiens.H3K27ac.b1               48550865
# 55             293T-PDS.GSE128106.Homo_Sapiens.YY1.b1               45904302
# 56            Ramos.GSE179755.Homo_Sapiens.H3K27ac.b1               42179029
# 57        lgs101645.GSE116193.Homo_Sapiens.H3K27ac.b1               41845040
# 58        lgs301315.GSE116193.Homo_Sapiens.H3K27ac.b1               39640737
# 59              BC1.GSE136090.Homo_Sapiens.H3K27ac.b1               39569105
# 60           lgs301315.GSE116193.Homo_Sapiens.CTCF.b1               39376017
# 61              BC3.GSE136090.Homo_Sapiens.H3K27ac.b1               38225847
# 62              JSC.GSE136090.Homo_Sapiens.H3K27ac.b1               36734111
# 63        lgs102943.GSE116193.Homo_Sapiens.H3K27ac.b1               35509764
# 64           lgs102943.GSE116193.Homo_Sapiens.CTCF.b1               35335748
# 65             Treg.GSE101498.Homo_Sapiens.H3K27ac.b1               31319366
# 66     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b1               12051488
#
#     Valid Interaction Pairs Number of 5kb Loops (Chr1 Only)  \
# 1                 445931504                             287
# 2                 234954564                             337
# 3                 151539207                              37
# 4                 380199595                             587
# 5                 347303698                             457
# 6                 145833436                            2949
# 7                 114952549                            2151
# 8                 134702211                              69
# 9                 191374595                             295
# 10                186439092                             249
# 11                104375182                             441
# 12                102261615                              36
# 13                168630830                             346
# 14                 97800990                             392
# 15                 24584547                            None
# 16                 76593777                             325
# 17                129610019                             329
# 18                118853962                             402
# 19                 89951377                             155
# 20                 72354257                             282
# 21                 62917771                              16
# 22                105977160                             396
# 23                 38015306                            1071
# 24                 96984223                             455
# 25                 71349144                             104
# 26                 81322898                             256
# 27                 68188485                             134
# 28                 46491751                            None
# 29                 31408907                            None
# 30                 33449237                            None
# 31                 27868879                            None
# 32                 69612885                            None
# 33                 56523486                             132
# 34                 37841966                            None
# 35                 36885673                            None
# 36                 42525103                             186
# 37                 48009927                              55
# 38                 23170231                            None
# 39                 15351518                            None
# 40                 29690624                               1
# 41                 21215608                             178
# 42                 21492716                            None
# 43                 12103970                            None
# 44                 34665842                              13
# 45                 22751546                             199
# 46                 30727420                               7
# 47                 30559861                               5
# 48                 12093604                            None
# 49                 25013643                              17
# 50                 26824960                               0
# 51                 25321243                              17
# 52                 17716612                               2
# 53                 11375543                               2
# 54                 18380230                              10
# 55                 14233750                            None
# 56                 17915546                               2
# 57                 21700174                               0
# 58                 20063791                               0
# 59                 12948113                               1
# 60                 19273695                              11
# 61                  9976222                            None
# 62                 11867302                               3
# 63                 18720816                               0
# 64                 18005883                               9
# 65                 15083091                            None
# 66                  5384572                            None
#
#    Number of 10kb Loops (Chr1 Only) Number of 25kb Loops (Chr1 Only)
# 1                               514                              601
# 2                               559                              532
# 3                               109                              290
# 4                               754                              626
# 5                               617                              519
# 6                              3259                             1931
# 7                              2353                             None
# 8                               148                              228
# 9                               481                              509
# 10                              354                              317
# 11                              527                              414
# 12                              119                              176
# 13                              598                              726
# 14                              498                              387
# 15                             None                                0
# 16                              473                              487
# 17                              550                              646
# 18                              642                              766
# 19                              241                              248
# 20                              449                              463
# 21                               49                              107
# 22                              619                              698
# 23                             1517                             1209
# 24                              661                              753
# 25                              195                              219
# 26                              450                              558
# 27                              230                              219
# 28                               48                               90
# 29                               50                               90
# 30                               26                               59
# 31                                4                               20
# 32                               28                              159
# 33                              364                              550
# 34                               17                              107
# 35                               10                               79
# 36                              335                              399
# 37                              197                              370
# 38                             None                             None
# 39                             None                                1
# 40                                2                               40
# 41                              278                              232
# 42                              834                              654
# 43                             None                               36
# 44                               32                               91
# 45                              574                              509
# 46                               19                               60
# 47                               20                              102
# 48                               39                               85
# 49                               58                              189
# 50                                4                               55
# 51                               86                              248
# 52                                8                               28
# 53                               11                               52
# 54                               23                               76
# 55                             None                             None
# 56                                5                               20
# 57                                3                               31
# 58                                6                               37
# 59                                2                                3
# 60                               55                              166
# 61                                0                                1
# 62                                4                               10
# 63                                1                               24
# 64                               35                              142
# 65                               29                               63
# 66                             None                                6

# %% [markdown]
# #### sort table by Valid Interaction Pairs (greatest to least)

# %%
loop_df = loop_df.sort_values(by=["Valid Interaction Pairs"], ascending=False).reset_index(drop=True)
loop_df.index += 1
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(loop_df)
# Out:
#                                           Sample Name  Total Pairs Processed  \
# 1              MyLa.GSE151193.Homo_Sapiens.H3K27ac.b1              736804619
# 2   HaCaT_Stimulated.GSE151193.Homo_Sapiens.H3K27a...              630181138
# 3   HaCaT_Unstimulated.GSE151193.Homo_Sapiens.H3K2...              574505628
# 4            HCASMC.GSE101498.Homo_Sapiens.H3K27ac.b1              722202094
# 5             AoSMC.GSE178598.Homo_Sapiens.H3K27ac.b1              337307006
# 6              HAEC.GSE178598.Homo_Sapiens.H3K27ac.b1              334543061
# 7              Treg.GSE101498.Homo_Sapiens.H3K27ac.b3              316205255
# 8             HAVIC.GSE154512.Homo_Sapiens.H3K27ac.b1              691966559
# 9                  H9.GSE105028.Homo_Sapiens.Rad21.b1              515530130
# 10        Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b1              364847796
# 11             Th17.GSE101498.Homo_Sapiens.H3K27ac.b3              241441720
# 12     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b3              220425415
# 13              H9-HS.GSE105028.Homo_Sapiens.Rad21.b1              418316089
# 14             Th17.GSE101498.Homo_Sapiens.H3K27ac.b2              204756067
# 15               GM.GSE101498.Homo_Sapiens.H3K27ac.b1              332279257
# 16        Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b2              316971810
# 17               GM.GSE101498.Homo_Sapiens.H3K27ac.b2              299478736
# 18     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b2              193547252
# 19             K562.GSE101498.Homo_Sapiens.H3K27ac.b1              213165389
# 20             Treg.GSE101498.Homo_Sapiens.H3K27ac.b2              160164015
# 21             MyLa.GSE101498.Homo_Sapiens.H3K27ac.b1              246037528
# 22             MyLa.GSE101498.Homo_Sapiens.H3K27ac.b2              212923142
# 23             K562.GSE101498.Homo_Sapiens.H3K27ac.b3              178162951
# 24        lgs000379.GSE116193.Homo_Sapiens.H3K27ac.b1              128447244
# 25             K562.GSE101498.Homo_Sapiens.H3K27ac.b2              155907950
# 26            H9-HS.GSE105028.Homo_Sapiens.H3K4me1.b1              208844380
# 27           lgs102580.GSE116193.Homo_Sapiens.CTCF.b1              107042962
# 28           lgs000379.GSE116193.Homo_Sapiens.CTCF.b1               92390968
# 29               H9-HS.GSE105028.Homo_Sapiens.OCT4.b1              153966714
# 30             Th17.GSE101498.Homo_Sapiens.H3K27ac.b1               92821305
# 31           H9-HS-KI.GSE105028.Homo_Sapiens.Rad21.b1              199983939
# 32                 H9.GSE105028.Homo_Sapiens.NANOG.b1              104440150
# 33              H9-HS.GSE105028.Homo_Sapiens.NANOG.b1               97626401
# 34  EBNA2_Plus_Ramos.GSE179755.Homo_Sapiens.H3K27a...               73912411
# 35                  H9.GSE105028.Homo_Sapiens.OCT4.b1              130955376
# 36               H9.GSE105028.Homo_Sapiens.H3K4me1.b1              135868209
# 37  EBNA2_Neg_Ramos.GSE179755.Homo_Sapiens.H3K27ac.b1               69443381
# 38        lgs102580.GSE116193.Homo_Sapiens.H3K27ac.b1               65520972
# 39           HCT116.GSE173699.Homo_Sapiens.H3K27ac.b1               89955822
# 40                  H9.GSE105028.Homo_Sapiens.KLF4.b1              130814263
# 41        lgs301283.GSE116193.Homo_Sapiens.H3K27ac.b1               52729360
# 42           lgs101645.GSE116193.Homo_Sapiens.CTCF.b1               50680134
# 43           lgs301283.GSE116193.Homo_Sapiens.CTCF.b1               53873305
# 44                 293T.GSE128106.Homo_Sapiens.YY1.b1              247695887
# 45          293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1               92276625
# 46               H9-HS.GSE105028.Homo_Sapiens.CTCF.b1               72025184
# 47        lgs101645.GSE116193.Homo_Sapiens.H3K27ac.b1               41845040
# 48                  H9.GSE105028.Homo_Sapiens.CTCF.b1               76803406
# 49             HT55.GSE147854.Homo_Sapiens.H3K27ac.b1               88687267
# 50        lgs301315.GSE116193.Homo_Sapiens.H3K27ac.b1               39640737
# 51           lgs301315.GSE116193.Homo_Sapiens.CTCF.b1               39376017
# 52        lgs102943.GSE116193.Homo_Sapiens.H3K27ac.b1               35509764
# 53             HARA.GSE147854.Homo_Sapiens.H3K27ac.b1               48550865
# 54           lgs102943.GSE116193.Homo_Sapiens.CTCF.b1               35335748
# 55            Ramos.GSE179755.Homo_Sapiens.H3K27ac.b1               42179029
# 56            BCBL1.GSE136090.Homo_Sapiens.H3K27ac.b1               50329964
# 57               H9-HS.GSE105028.Homo_Sapiens.KLF4.b1               92095681
# 58             Treg.GSE101498.Homo_Sapiens.H3K27ac.b1               31319366
# 59             293T-PDS.GSE128106.Homo_Sapiens.YY1.b1               45904302
# 60              BC1.GSE136090.Homo_Sapiens.H3K27ac.b1               39569105
# 61    H9-siNIPBL-HS.GSE105028.Homo_Sapiens.H3K4me1.b1               74434067
# 62       H9-siNIPBL-HS.GSE105028.Homo_Sapiens.CTCF.b1               56100419
# 63              JSC.GSE136090.Homo_Sapiens.H3K27ac.b1               36734111
# 64               HCT116.GSE92881.Homo_Sapiens.SMC1.b1               49965377
# 65              BC3.GSE136090.Homo_Sapiens.H3K27ac.b1               38225847
# 66     Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b1               12051488
#
#     Valid Interaction Pairs Number of 5kb Loops (Chr1 Only)  \
# 1                 445931504                             287
# 2                 380199595                             587
# 3                 347303698                             457
# 4                 234954564                             337
# 5                 191374595                             295
# 6                 186439092                             249
# 7                 168630830                             346
# 8                 151539207                              37
# 9                 145833436                            2949
# 10                134702211                              69
# 11                129610019                             329
# 12                118853962                             402
# 13                114952549                            2151
# 14                105977160                             396
# 15                104375182                             441
# 16                102261615                              36
# 17                 97800990                             392
# 18                 96984223                             455
# 19                 89951377                             155
# 20                 81322898                             256
# 21                 76593777                             325
# 22                 72354257                             282
# 23                 71349144                             104
# 24                 69612885                            None
# 25                 68188485                             134
# 26                 62917771                              16
# 27                 56523486                             132
# 28                 48009927                              55
# 29                 46491751                            None
# 30                 42525103                             186
# 31                 38015306                            1071
# 32                 37841966                            None
# 33                 36885673                            None
# 34                 34665842                              13
# 35                 33449237                            None
# 36                 31408907                            None
# 37                 30727420                               7
# 38                 30559861                               5
# 39                 29690624                               1
# 40                 27868879                            None
# 41                 26824960                               0
# 42                 25321243                              17
# 43                 25013643                              17
# 44                 24584547                            None
# 45                 23170231                            None
# 46                 22751546                             199
# 47                 21700174                               0
# 48                 21492716                            None
# 49                 21215608                             178
# 50                 20063791                               0
# 51                 19273695                              11
# 52                 18720816                               0
# 53                 18380230                              10
# 54                 18005883                               9
# 55                 17915546                               2
# 56                 17716612                               2
# 57                 15351518                            None
# 58                 15083091                            None
# 59                 14233750                            None
# 60                 12948113                               1
# 61                 12103970                            None
# 62                 12093604                            None
# 63                 11867302                               3
# 64                 11375543                               2
# 65                  9976222                            None
# 66                  5384572                            None
#
#    Number of 10kb Loops (Chr1 Only) Number of 25kb Loops (Chr1 Only)
# 1                               514                              601
# 2                               754                              626
# 3                               617                              519
# 4                               559                              532
# 5                               481                              509
# 6                               354                              317
# 7                               598                              726
# 8                               109                              290
# 9                              3259                             1931
# 10                              148                              228
# 11                              550                              646
# 12                              642                              766
# 13                             2353                             None
# 14                              619                              698
# 15                              527                              414
# 16                              119                              176
# 17                              498                              387
# 18                              661                              753
# 19                              241                              248
# 20                              450                              558
# 21                              473                              487
# 22                              449                              463
# 23                              195                              219
# 24                               28                              159
# 25                              230                              219
# 26                               49                              107
# 27                              364                              550
# 28                              197                              370
# 29                               48                               90
# 30                              335                              399
# 31                             1517                             1209
# 32                               17                              107
# 33                               10                               79
# 34                               32                               91
# 35                               26                               59
# 36                               50                               90
# 37                               19                               60
# 38                               20                              102
# 39                                2                               40
# 40                                4                               20
# 41                                4                               55
# 42                               86                              248
# 43                               58                              189
# 44                             None                                0
# 45                             None                             None
# 46                              574                              509
# 47                                3                               31
# 48                              834                              654
# 49                              278                              232
# 50                                6                               37
# 51                               55                              166
# 52                                1                               24
# 53                               23                               76
# 54                               35                              142
# 55                                5                               20
# 56                                8                               28
# 57                             None                                1
# 58                               29                               63
# 59                             None                             None
# 60                                2                                3
# 61                             None                               36
# 62                               39                               85
# 63                                4                               10
# 64                               11                               52
# 65                                0                                1
# 66                             None                                6

# %% [markdown]
# ## Plot HiCCUPS Loops versus Valid Pairs

# %% [markdown]
# #### give "None" entries a value of 0

# %%
plot_data = loop_df.copy()
plot_data.loc[:, 'Number of 5kb Loops (Chr1 Only)'] = \
    plot_data.loc[:, 'Number of 5kb Loops (Chr1 Only)'].replace('None', 0)
plot_data.loc[:, 'Number of 10kb Loops (Chr1 Only)'] = \
    plot_data.loc[:, 'Number of 10kb Loops (Chr1 Only)'].replace('None', 0)
plot_data.loc[:, 'Number of 25kb Loops (Chr1 Only)'] = \
    plot_data.loc[:, 'Number of 25kb Loops (Chr1 Only)'].replace('None', 0)

# %% [markdown]
# #### distrubutions of each loop type

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
#fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.displot(plot_data, bins=50, x="Number of 5kb Loops (Chr1 Only)")
plot_data["Number of 5kb Loops (Chr1 Only)"].describe()
# Out:
# count      66.000000
# mean      203.151515
# std       467.154339
# min         0.000000
# 25%         0.000000
# 50%        14.500000
# 75%       275.500000
# max      2949.000000
# Name: Number of 5kb Loops (Chr1 Only), dtype: float64

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
#fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.displot(plot_data, bins=50, x="Number of 10kb Loops (Chr1 Only)")
plot_data["Number of 10kb Loops (Chr1 Only)"].describe()
# Out:
# count      66.000000
# mean      305.651515
# std       538.279210
# min         0.000000
# 25%         8.500000
# 50%        56.500000
# 75%       479.000000
# max      3259.000000
# Name: Number of 10kb Loops (Chr1 Only), dtype: float64

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
#fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.displot(plot_data, bins=50, x="Number of 25kb Loops (Chr1 Only)")
plot_data["Number of 25kb Loops (Chr1 Only)"].describe()
# Out:
# count      66.000000
# mean      280.500000
# std       334.371431
# min         0.000000
# 25%        43.000000
# 50%       162.500000
# 75%       481.000000
# max      1931.000000
# Name: Number of 25kb Loops (Chr1 Only), dtype: float64

# %%
np.percentile(plot_data["Number of 25kb Loops (Chr1 Only)"], [5, 10, 15, 20])
# Out:
# array([ 0.25,  4.5 , 20.  , 31.  ])

# %% [markdown]
# #### plot valid interaction pairs vs. number 25kb loops

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(fig, left=True, bottom=True)

sns.scatterplot(x="Valid Interaction Pairs",
                y="Number of 25kb Loops (Chr1 Only)",
                data=plot_data,
                ax=ax)
# Out:
# <AxesSubplot:xlabel='Valid Interaction Pairs', ylabel='Number of 25kb Loops (Chr1 Only)'>

# %% [markdown]
# #### plot valid interaction pairs vs. number 10kb loops

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(fig, left=True, bottom=True)

sns.scatterplot(x="Valid Interaction Pairs",
                y="Number of 10kb Loops (Chr1 Only)",
                data=plot_data,
                ax=ax)
# Out:
# <AxesSubplot:xlabel='Valid Interaction Pairs', ylabel='Number of 10kb Loops (Chr1 Only)'>

# %% [markdown]
# #### plot valid interaction pairs vs. number 5kb loops

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(fig, left=True, bottom=True)

sns.scatterplot(x="Valid Interaction Pairs",
                y="Number of 5kb Loops (Chr1 Only)",
                data=plot_data,
                ax=ax)
# Out:
# <AxesSubplot:xlabel='Valid Interaction Pairs', ylabel='Number of 5kb Loops (Chr1 Only)'>

# %% [markdown]
# ## Plotting Loops versus Valid Pairs using a Soft Threshold

# %%
soft_threshold = 1e8
soft_data = plot_data.loc[plot_data['Valid Interaction Pairs'] < soft_threshold]

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(fig, left=True, bottom=True)

sns.scatterplot(x="Valid Interaction Pairs",
                y="Number of 25kb Loops (Chr1 Only)",
                data=soft_data,
                ax=ax)
# Out:
# <AxesSubplot:xlabel='Valid Interaction Pairs', ylabel='Number of 25kb Loops (Chr1 Only)'>

# %% [markdown]
# ### Proposed Threshold: discard samples with <20 million interaction pairs OR <20 25kb HiCCUPS loops

# %% [markdown]
# ### Decided Threshold: >200 10kb HiCCUPS loops
