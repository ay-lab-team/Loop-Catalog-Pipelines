# %%
import os
import sys
import pandas as pd
import tracker
latest_date = tracker.processing_dates[-1]
os.chdir('/mnt/BioAdHoc/Groups/vd-ay/kfetter/hichip-db-loop-calling/')

# %%
latest_date
# Out:
# '2022.06.27.09.17'

# %%
# setting input and output with jupyter notebook in context 
if 'ipykernel_launcher.py' in sys.argv[0]:
    input_fn = 'results/samplesheets/fastq/{}.fastq.google-samplesheet.tsv'.format(latest_date)
    output_prefix = 'results/samplesheets/fastq/{}.fastq.samplesheet'.format(latest_date)
# if not using jupyter notebook
else:
    input_fn = sys.argv[1]
    output_prefix = sys.argv[2]

# %%
# loading the samplesheet
df = pd.read_table(input_fn, skiprows=0)

# %%
df
# Out:
#     Sample Name (as used in the server)                   Study     GSE ID  \
# 0                                    GM    Mumbach et al., 2017  GSE101498
# 1                                    GM    Mumbach et al., 2017  GSE101498
# 2                                  K562    Mumbach et al., 2017  GSE101498
# 3                                  K562    Mumbach et al., 2017  GSE101498
# 4                                  K562    Mumbach et al., 2017  GSE101498
# ..                                  ...                     ...        ...
# 480                                K562  Weintraub et al., 2017   GSE99519
# 481                             iPSC-WT      Kraft et al., 2022  GSE150906
# 482                             iPSC-WT      Kraft et al., 2022  GSE150906
# 483                            iPSC-MUT      Kraft et al., 2022  GSE150906
# 484                            iPSC-MUT      Kraft et al., 2022  GSE150906
#
#          GSM ID       SRR ID                                   GEO Title  \
# 0    GSM2705041   SRR5831489    GM HiChIP H3K27ac biological replicate 1
# 1    GSM2705042   SRR5831490    GM HiChIP H3K27ac biological replicate 2
# 2    GSM2705043   SRR5831491  K562 HiChIP H3K27ac biological replicate 1
# 3    GSM2705044   SRR5831492  K562 HiChIP H3K27ac biological replicate 2
# 4    GSM2705045   SRR5831493  K562 HiChIP H3K27ac biological replicate 3
# ..          ...          ...                                         ...
# 480  GSM2774002   SRR6010263                             HiChIP_K562_YY1
# 481  GSM4560486  SRR11816734                   iPSC_WT_A_H3K27me3_HiChIP
# 482  GSM4560487  SRR11816735                   iPSC_WT_B_H3K27me3_HiChIP
# 483  GSM4560488  SRR11816736                  iPSC_MUT_A_H3K27me3_HiChIP
# 484  GSM4560489  SRR11816737                  iPSC_MUT_B_H3K27me3_HiChIP
#
#                                  GEO Source  \
# 0                         GM12878 cell line
# 1                         GM12878 cell line
# 2                            K562 cell line
# 3                            K562 cell line
# 4                            K562 cell line
# ..                                      ...
# 480                         HiChIP_K562_YY1
# 481                          wild-type iPSC
# 482                          wild-type iPSC
# 483  RNA-binding deficient EZH2 mutant iPSC
# 484  RNA-binding deficient EZH2 mutant iPSC
#
#                                        GEO Description      Organism  \
# 0    Protein-enriched long-range contact; GM_HiChIP...  Homo sapiens
# 1    Protein-enriched long-range contact; GM_HiChIP...  Homo sapiens
# 2    Protein-enriched long-range contact; K562_HiCh...  Homo sapiens
# 3    Protein-enriched long-range contact; K562_HiCh...  Homo sapiens
# 4    Protein-enriched long-range contact; K562_HiCh...  Homo sapiens
# ..                                                 ...           ...
# 480                                                NaN  Homo sapiens
# 481  H3K27me3 HiChIP library; iPSC_wt6_K1-TAAGGCGA-...  Homo sapiens
# 482  H3K27me3 HiChIP library; iPSC_wt7_K3-AGGCAGAA-...  Homo sapiens
# 483  H3K27me3 HiChIP library; iPSC_mut18_K5-GGACTCC...  Homo sapiens
# 484  H3K27me3 HiChIP library; iPSC_mut20_K7-CTCTCTA...  Homo sapiens
#
#     Number of Reads  ...  HiCPro Status  HiChIP Peaks Status hichipper Status  \
# 0       664,558,514  ...              1                    0                0
# 1       598,957,472  ...              1                    0                0
# 2       426,330,778  ...              1                    0                0
# 3       311,815,900  ...              1                    0                0
# 4       356,325,902  ...              1                    0                0
# ..              ...  ...            ...                  ...              ...
# 480       158111028  ...              1                    0                0
# 481       195443840  ...              1                    0                0
# 482        28509234  ...              1                    0                0
# 483       309053672  ...              1                    0                0
# 484       112548012  ...              1                    0                0
#
#      OTHER Status  FitHiChIP Status  Operator Priority  Cluster Path/Branch  \
# 0               0                 0   Joaquin      NaN                  NaN
# 1               0                 0   Joaquin      NaN                  NaN
# 2               0                 0   Joaquin      NaN                  NaN
# 3               0                 0   Joaquin      NaN                  NaN
# 4               0                 0   Joaquin      NaN                  NaN
# ..            ...               ...       ...      ...                  ...
# 480             0                 0   Joaquin      NaN                  NaN
# 481             0                 0   Joaquin      NaN                  NaN
# 482             0                 0   Joaquin      NaN                  NaN
# 483             0                 0   Joaquin      NaN                  NaN
# 484             0                 0   Joaquin      NaN                  NaN
#
#         Date Added  Comments
# 0    pre-5/16/2022       NaN
# 1    pre-5/16/2022       NaN
# 2    pre-5/16/2022       NaN
# 3    pre-5/16/2022       NaN
# 4    pre-5/16/2022       NaN
# ..             ...       ...
# 480      5/16/2022       NaN
# 481      6/16/2022       NaN
# 482      6/16/2022       NaN
# 483      6/16/2022       NaN
# 484      6/16/2022       NaN
#
# [485 rows x 26 columns]

# %%
# extract those samples which are ready for processing
ready_df = df.loc[(df['Start Processing'] == 1) & (df['Download Status'] == 0) & (df['Operator'] == "Kyra")]

# extract only the columns needed
major_cols = ['Sample Name (as used in the server)',
 'GSE ID',
 'GSM ID',
 'SRR ID',
 'Organism',
 'Biological Replicate Serial No',
 'Technical Replicate Serial No',
 'ChIP-seq Pull Down',
 'Restriction Enzyme']
ready_df = ready_df[major_cols]

# %%
# capitalizes organism
def parse_organism(string):
    new_words = []
    for word in string.split():
        new_words.append(word.capitalize())
    new_string = '_'.join(new_words)
    return(new_string)

ready_df.loc[:, 'Organism'] = ready_df.loc[:, 'Organism'].apply(parse_organism)

# %%
# getting the sample names
sample_names = []
for i, sr in ready_df.iterrows():
    sample_name = '{sample_name}.{gse_id}.{organism}.{antibody_target}.b{biological_rep}'
    sample_name = sample_name.format(sample_name=sr[0],
                                     gse_id=sr[1],
                                     organism=sr[4],
                                     antibody_target=sr[7], 
                                     biological_rep=sr[5])
    sample_names.append(sample_name)
ready_df.loc[:, 'sample_name'] = sample_names

# %%
# renaming the columns for easy computational use 
ready_df.columns = ['sample_name', 'gse_id', 'gsm_id', 'srr_id',
                    'organism', 'bio_rep', 'tech_rep', 'antibody_target',
                    'restriction_enzyme', 'std_sample_name']

# %%
# reorder the columns
reorder = ['std_sample_name',
             'gse_id',
             'gsm_id',
             'srr_id',
             'organism',
             'bio_rep',
             'tech_rep',
             'antibody_target',
             'restriction_enzyme',
             'sample_name']
ready_df = ready_df[reorder]

# %%
ready_df
# Out:
#                                        std_sample_name     gse_id      gsm_id  \
# 37           A673_SA1m1.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227  GSM3902791
# 38           A673_SA1m1.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227  GSM3902792
# 39           A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b1  GSE133227  GSM3902793
# 40           A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b2  GSE133227  GSM3902794
# 41           A673_SA2m1.GSE133227.Homo_Sapiens.CTCF.b3  GSE133227  GSM3902795
# ..                                                 ...        ...         ...
# 411            DND41.GSE165207.Homo_Sapiens.H3K27ac.b2  GSE165207  GSM5028230
# 412            DND41.GSE165207.Homo_Sapiens.H3K27ac.b2  GSE165207  GSM5028230
# 413           Jurkat.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207  GSM5028231
# 414           Jurkat.GSE165207.Homo_Sapiens.H3K27ac.b1  GSE165207  GSM5028231
# 415  CD34+-Cord-Blood.GSE165207.Homo_Sapiens.H3K27a...  GSE165207  GSM5028232
#
#           srr_id      organism  bio_rep  tech_rep antibody_target  \
# 37    SRR9590180  Homo_Sapiens        1         1            CTCF
# 38    SRR9590181  Homo_Sapiens        2         1            CTCF
# 39    SRR9590182  Homo_Sapiens        1         1            CTCF
# 40    SRR9590183  Homo_Sapiens        2         1            CTCF
# 41    SRR9590184  Homo_Sapiens        3         1            CTCF
# ..           ...           ...      ...       ...             ...
# 411  SRR13492047  Homo_Sapiens        2         1         H3K27ac
# 412  SRR13492048  Homo_Sapiens        2         2         H3K27ac
# 413  SRR13492049  Homo_Sapiens        1         1         H3K27ac
# 414  SRR13492050  Homo_Sapiens        1         2         H3K27ac
# 415  SRR13492051  Homo_Sapiens        1         1         H3K27ac
#
#     restriction_enzyme       sample_name
# 37                MboI        A673_SA1m1
# 38                MboI        A673_SA1m1
# 39                MboI        A673_SA2m1
# 40                MboI        A673_SA2m1
# 41                MboI        A673_SA2m1
# ..                 ...               ...
# 411              Arima             DND41
# 412              Arima             DND41
# 413              Arima            Jurkat
# 414              Arima            Jurkat
# 415              Arima  CD34+-Cord-Blood
#
# [103 rows x 10 columns]

# %%
header_output = '{}.with_header.tsv'.format(output_prefix)
ready_df.to_csv(header_output, header=True, index=False, sep='\t')

without_header_output = '{}.without_header.tsv'.format(output_prefix)
ready_df.to_csv(without_header_output, header=False, index=False, sep='\t')

# %%
df.shape
# Out:
# (485, 26)

# %%
ready_df.shape
# Out:
# (103, 10)
