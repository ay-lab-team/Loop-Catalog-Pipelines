# %%
import os
import sys
import pandas as pd
import tracker
latest_date = tracker.processing_dates[-1]
os.chdir('/mnt/bioadhoc-temp/Groups/vd-ay/kfetter/hichip-db-loop-calling/')

# %%
latest_date='2022.10.20.09.39'

# %%
# setting input and output with jupyter notebook in context 
if 'ipykernel_launcher.py' in sys.argv[0]:
    input_fn = 'results/samplesheets/fastq/{}.fastq.google-samplesheet.tsv'.format(latest_date)
    output_prefix = 'results/samplesheets/fastq/{}.fastq.samplesheet'.format(latest_date)
# if not using jupyter notebook
else:
    input_fn = sys.argv[1]
    output_prefix = sys.argv[2]

# %%
# loading the samplesheet
df = pd.read_table(input_fn, skiprows=0)

# %%
df
# Out:
#     Sample Name (as used in the server)                   Study  \
# 0                                  293T         Li et al., 2020
# 1                                  293T         Li et al., 2020
# 2                                  293T         Li et al., 2020
# 3                                  293T         Li et al., 2020
# 4                              293T-PDS         Li et al., 2020
# ..                                  ...                     ...
# 756          Nonclassical_Monocyte_1831  Schmiedel et al., 2021
# 757          Nonclassical_Monocyte_1831  Schmiedel et al., 2021
# 758          Nonclassical_Monocyte_1831  Schmiedel et al., 2021
# 759          Nonclassical_Monocyte_1831  Schmiedel et al., 2021
# 760          Nonclassical_Monocyte_1831  Schmiedel et al., 2021
#
#             GSE ID      GSM ID      SRR ID            GEO Title  \
# 0        GSE128106  GSM3664990  SRR8707613      HiChIP YY1 rep1
# 1        GSE128106  GSM3664991  SRR8707614      HiChIP YY1 rep2
# ...

# %%
# extract those samples which are ready for processing
ready_df = df.loc[(df['HiCPro Status'] == 1)]

# extract only the columns needed
major_cols = ['Sample Name (as used in the server)',
 'GSE ID',
 'GSM ID',
 'SRR ID',
 'Organism',
 'Biological Replicate Serial No',
 'Technical Replicate Serial No',
 'ChIP-seq Pull Down',
 'Restriction Enzyme']
ready_df = ready_df[major_cols]

# %%
ready_df
# Out:
#     Sample Name (as used in the server)         GSE ID      GSM ID  \
# 0                                  293T      GSE128106  GSM3664990
# 1                                  293T      GSE128106  GSM3664991
# 2                                  293T      GSE128106  GSM3664992
# 3                                  293T      GSE128106  GSM3664993
# 4                              293T-PDS      GSE128106  GSM3664994
# ..                                  ...            ...         ...
# 756          Nonclassical_Monocyte_1831  phs001703v4p1         NaN
# 757          Nonclassical_Monocyte_1831  phs001703v4p1         NaN
# 758          Nonclassical_Monocyte_1831  phs001703v4p1         NaN
# 759          Nonclassical_Monocyte_1831  phs001703v4p1         NaN
# 760          Nonclassical_Monocyte_1831  phs001703v4p1         NaN
#
#          SRR ID      Organism  Biological Replicate Serial No  \
# 0    SRR8707613  Homo sapiens                               1
# ...

# %%
# capitalizes organism
def parse_organism(string):
    new_words = []
    for word in string.split():
        new_words.append(word.capitalize())
    new_string = '_'.join(new_words)
    return(new_string)

ready_df.loc[:, 'Organism'] = ready_df.loc[:, 'Organism'].apply(parse_organism)

# %%
# getting the sample names
sample_names = []
for i, sr in ready_df.iterrows():
    sample_name = '{sample_name}.{gse_id}.{organism}.{antibody_target}.b{biological_rep}'
    sample_name = sample_name.format(sample_name=sr[0],
                                     gse_id=sr[1],
                                     organism=sr[4],
                                     antibody_target=sr[7], 
                                     biological_rep=str(sr[5])[0])
    sample_names.append(sample_name)
ready_df.loc[:, 'sample_name'] = sample_names

# %%
# renaming the columns for easy computational use 
ready_df.columns = ['sample_name', 'gse_id', 'gsm_id', 'srr_id',
                    'organism', 'bio_rep', 'tech_rep', 'antibody_target',
                    'restriction_enzyme', 'std_sample_name']

# %%
# reorder the columns
reorder = ['std_sample_name',
             'gse_id',
             'gsm_id',
             'srr_id',
             'organism',
             'bio_rep',
             'tech_rep',
             'antibody_target',
             'restriction_enzyme',
             'sample_name']
ready_df = ready_df[reorder]

# %%
ready_df
# Out:
#                                        std_sample_name         gse_id  \
# 0                   293T.GSE128106.Homo_Sapiens.YY1.b1      GSE128106
# 1                   293T.GSE128106.Homo_Sapiens.YY1.b1      GSE128106
# 2                   293T.GSE128106.Homo_Sapiens.YY1.b1      GSE128106
# 3                   293T.GSE128106.Homo_Sapiens.YY1.b1      GSE128106
# 4               293T-PDS.GSE128106.Homo_Sapiens.YY1.b1      GSE128106
# ..                                                 ...            ...
# 756  Nonclassical_Monocyte_1831.phs001703v4p1.Homo_...  phs001703v4p1
# 757  Nonclassical_Monocyte_1831.phs001703v4p1.Homo_...  phs001703v4p1
# 758  Nonclassical_Monocyte_1831.phs001703v4p1.Homo_...  phs001703v4p1
# 759  Nonclassical_Monocyte_1831.phs001703v4p1.Homo_...  phs001703v4p1
# 760  Nonclassical_Monocyte_1831.phs001703v4p1.Homo_...  phs001703v4p1
#
#          gsm_id      srr_id      organism  bio_rep  tech_rep antibody_target  \
# ...

# %%
header_output = '{}.with_header.tsv'.format(output_prefix)
ready_df.to_csv(header_output, header=True, index=False, sep='\t')

without_header_output = '{}.without_header.tsv'.format(output_prefix)
ready_df.to_csv(without_header_output, header=False, index=False, sep='\t')

# %%
df.shape
# Out:
# (761, 54)

# %%
ready_df.shape
# Out:
# (755, 10)

# %%
def get_cell(row):
    if row['std_sample_name'].split('_1')[0] == 'CD4_Naive':
          return 'CD4_Naive'
    if row['std_sample_name'].split('_1')[0] == 'CD8_Naive':
          return 'CD8_Naive'
    if row['std_sample_name'].split('_1')[0] == 'Monocyte':
          return 'Monocyte'
    if row['std_sample_name'].split('_1')[0] == 'Naive_B':
          return 'Naive_B'
    if row['std_sample_name'].split('_1')[0] == 'Naive_K':
          return 'Naive_K'

# %%
def get_donor(row):
    if row['std_sample_name'].split('.')[0].split('-RH')[0].split('_')[-1] == '1800':
          return 'Donor1'
    if row['std_sample_name'].split('.')[0].split('-RH')[0].split('_')[-1] == '1814':
          return 'Donor2'
    if row['std_sample_name'].split('.')[0].split('-RH')[0].split('_')[-1] == '1815':
          return 'Donor3'
    if row['std_sample_name'].split('.')[0].split('-RH')[0].split('_')[-1] == '1816':
          return 'Donor4'
    if row['std_sample_name'].split('.')[0].split('-RH')[0].split('_')[-1] == '1829':
          return 'Donor5'
    if row['std_sample_name'].split('.')[0].split('-RH')[0].split('_')[-1] == '1831':
          return 'Donor6'

# %%
fin_df = ready_df.copy(deep=True)
fin_df = fin_df.drop(columns=['gsm_id', 'srr_id', 'organism', 'antibody_target', 'restriction_enzyme', 'sample_name'])
pie_df = fin_df.loc[fin_df['gse_id'] == 'phs001703v3p1'].reset_index(drop=True)
pie_df
# Out:
#                                        std_sample_name         gse_id  \
# 0    CD4_Naive_1800-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 1    CD4_Naive_1814-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 2    CD4_Naive_1815-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 3    CD4_Naive_1815-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 4    CD4_Naive_1816-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# ..                                                 ...            ...
# 139  Naive_K_1816-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 140  Naive_K_1829-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 141  Naive_K_1829-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 142  Naive_K_1831-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 143  Naive_K_1831-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
#
#      bio_rep  tech_rep
# 0          1         1
# 1          1         1
# 2          1         1
# 3          1         2
# ...

# %%
import glob
cells = ['CD4_Naive', 'CD8_Naive', 'Monocyte', 'Naive_B', 'Naive_K']
tl = '/mnt/BioAdHoc/Groups/vd-vijay/sourya/Projects/2018_HiChIP_FiveImmuneCell_Vivek/Data_Submission/HiChIP/{cell_type}/Donor_Specific_Fastq/S{bio_rep}/*.fastq.gz'
fastqs = []

for cell in cells:
    for rep in [1, 2, 3]:
        samples = glob.glob(tl.format(cell_type=cell, bio_rep=rep))
        for sample in samples:
            fastqs.append(sample)

# %%
all_sample_fastqs = []
for index, row in pie_df.iterrows():
    #print(row['std_sample_name'])
    donor = get_donor(row)
    cell = get_cell(row)
    sample_fastqs = [file for file in fastqs if donor in file and cell in file and file.split('/')[12][-1] == str(row['bio_rep'])]
    sample_fastqs.insert(0, row['std_sample_name'])
    #print(sample_fastqs)
    if sample_fastqs not in all_sample_fastqs:  
        all_sample_fastqs.append(sample_fastqs)
    #print()
    sample_fastqs = []
fastqs_df = pd.DataFrame(all_sample_fastqs)
columns = ['std_sample_name', 'file_1', 'file_2', 'file_3', 'file_4', 'file_5', 'file_6', 'file_7', 'file_8']
fastqs_df.columns = columns
pie_df = pie_df.merge(fastqs_df)
pie_df
# Out:
#                                        std_sample_name         gse_id  \
# 0    CD4_Naive_1800-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 1    CD4_Naive_1814-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 2    CD4_Naive_1815-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 3    CD4_Naive_1815-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# 4    CD4_Naive_1816-RH-1.phs001703v3p1.Homo_Sapiens...  phs001703v3p1
# ..                                                 ...            ...
# 139  Naive_K_1816-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 140  Naive_K_1829-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 141  Naive_K_1829-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 142  Naive_K_1831-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
# 143  Naive_K_1831-RH-1.phs001703v3p1.Homo_Sapiens.H...  phs001703v3p1
#
#      bio_rep  tech_rep                                             file_1  \
# ...

# %%
without_header_output = '{}.without_header.tsv'.format('/mnt/BioAdHoc/Groups/vd-ay/kfetter/hichip-db-loop-calling/results/samplesheets/fastq/pieqtl_files.samplesheet')
pie_df.to_csv(without_header_output, header=False, index=False, sep='\t')

# %%
fin_df = ready_df.copy(deep=True)
fin_df = fin_df.drop(columns=['gsm_id', 'srr_id', 'organism', 'antibody_target', 'restriction_enzyme', 'sample_name'])
nm_df = fin_df.loc[fin_df['gse_id'] == 'phs001703v4p1'].reset_index(drop=True)
nm_df
# Out:
#                                       std_sample_name         gse_id  bio_rep  \
# 0   Nonclassical_Monocyte_1786.phs001703v4p1.Homo_...  phs001703v4p1        1
# 1   Nonclassical_Monocyte_1786.phs001703v4p1.Homo_...  phs001703v4p1        1
# 2   Nonclassical_Monocyte_1786.phs001703v4p1.Homo_...  phs001703v4p1        2
# 3   Nonclassical_Monocyte_1786.phs001703v4p1.Homo_...  phs001703v4p1        2
# 4   Nonclassical_Monocyte_1786.phs001703v4p1.Homo_...  phs001703v4p1        3
# 5   Nonclassical_Monocyte_1786.phs001703v4p1.Homo_...  phs001703v4p1        4
# 6   Nonclassical_Monocyte_1800.phs001703v4p1.Homo_...  phs001703v4p1        1
# 7   Nonclassical_Monocyte_1800.phs001703v4p1.Homo_...  phs001703v4p1        1
# 8   Nonclassical_Monocyte_1800.phs001703v4p1.Homo_...  phs001703v4p1        2
# 9   Nonclassical_Monocyte_1800.phs001703v4p1.Homo_...  phs001703v4p1        2
# 10  Nonclassical_Monocyte_1800.phs001703v4p1.Homo_...  phs001703v4p1        3
# ...

# %%
import glob
tl = '/mnt/BioAdHoc/Groups/vd-vijay/sourya/Projects/2019_HiChIP_CD4_Subtypes_Vivek/Data_Submission/HiChIP/fastqs/NCM/{donor_id}/*.fastq.gz'
fastqs = []

for donor in ['1786', '1800', '1814', '1815', '1816', '1831']:
    samples = glob.glob(tl.format(donor_id=donor))
    for sample in samples:
        fastqs.append(sample)

# %%
all_sample_fastqs = []
for index, row in nm_df.iterrows():
    print(row['std_sample_name'])
    donor = row['std_sample_name'].split('.')[0].split('_')[2]
    sample_fastqs = [file for file in fastqs if donor in file and file.split('/')[13].split('_')[1][-1] == str(row['bio_rep'])]
    sample_fastqs.insert(0, row['std_sample_name'])
    print(sample_fastqs)
    if sample_fastqs not in all_sample_fastqs:  
        all_sample_fastqs.append(sample_fastqs)
    print()
    sample_fastqs = []
fastqs_df = pd.DataFrame(all_sample_fastqs)
columns = ['std_sample_name', 'file_1', 'file_2', 'file_3', 'file_4']
fastqs_df.columns = columns
nm_df = nm_df.merge(fastqs_df)
nm_df
# Out:
# Nonclassical_Monocyte_1786.phs001703v4p1.Homo_Sapiens.H3K27ac.b1
# ['Nonclassical_Monocyte_1786.phs001703v4p1.Homo_Sapiens.H3K27ac.b1', '/mnt/BioAdHoc/Groups/vd-vijay/sourya/Projects/2019_HiChIP_CD4_Subtypes_Vivek/Data_Submission/HiChIP/fastqs/NCM/1786/1786_Run1_RH1_C50_L002_R1.fastq.gz', '/mnt/BioAdHoc/Groups/vd-vijay/sourya/Projects/2019_HiChIP_CD4_Subtypes_Vivek/Data_Submission/HiChIP/fastqs/NCM/1786/1786_Run1_RH1_C50_L001_R2.fastq.gz', '/mnt/BioAdHoc/Groups/vd-vijay/sourya/Projects/2019_HiChIP_CD4_Subtypes_Vivek/Data_Submission/HiChIP/fastqs/NCM/1786/1786_Run1_RH1_C50_L001_R1.fastq.gz', '/mnt/BioAdHoc/Groups/vd-vijay/sourya/Projects/2019_HiChIP_CD4_Subtypes_Vivek/Data_Submission/HiChIP/fastqs/NCM/1786/1786_Run1_RH1_C50_L002_R2.fastq.gz']
#
# Nonclassical_Monocyte_1786.phs001703v4p1.Homo_Sapiens.H3K27ac.b1
# ...

# %%
without_header_output = '{}.without_header.tsv'.format('/mnt/BioAdHoc/Groups/vd-ay/kfetter/hichip-db-loop-calling/results/samplesheets/fastq/nm_files.samplesheet')
nm_df.to_csv(without_header_output, header=False, index=False, sep='\t')
