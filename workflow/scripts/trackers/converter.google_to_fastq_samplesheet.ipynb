# %%
import os
import sys
import pandas as pd
import tracker
latest_date = tracker.processing_dates[-1]
os.chdir('/mnt/BioAdHoc/Groups/vd-ay/hichip-db-loop-calling/')

# %%
# setting input and output with jupyter notebook in context 
if 'ipykernel_launcher.py' in sys.argv[0]:
    input_fn = 'results/samplesheets/fastq/{}.fastq.google-samplesheet.tsv'.format(latest_date)
    output_prefix = 'results/samplesheets/fastq/{}.fastq.samplesheet'.format(latest_date)
else:
    input_fn = sys.argv[1]
    output_prefix = sys.argv[2]

# %%
latest_date
# Out:
# '2022.04.09.16.57'

# %%
# loading the samplesheet
df = pd.read_table(input_fn, skiprows=1)

# %%
df
# Out:
#     Sample Name (as used in the server)                  Study     GSE ID  \
# 0                         mES_25m_cells   Mumbach et al., 2017  GSE101498
# 1                         mES_25m_cells   Mumbach et al., 2017  GSE101498
# 2                         mES_25m_cells   Mumbach et al., 2017  GSE101498
# 3                         mES_25m_cells   Mumbach et al., 2017  GSE101498
# 4                        mES_500k_cells   Mumbach et al., 2017  GSE101498
# ..                                  ...                    ...        ...
# 178                            293T-PDS        Li et al., 2020  GSE128106
# 179                            293T-PDS        Li et al., 2020  GSE128106
# 180                         293T-TMPYP4        Li et al., 2020  GSE128106
# 181                         293T-TMPYP4        Li et al., 2020  GSE128106
# 182                              HCT116  Schuijers et al. 2018   GSE92881
#
#          GSM ID      SRR ID  \
# 0    GSM2705031  SRR5831479
# 1    GSM2705032  SRR5831480
# 2    GSM2705033  SRR5831481
# 3    GSM2705034  SRR5831482
# 4    GSM2705035  SRR5831483
# ..          ...         ...
# 178  GSM3664994  SRR8707617
# 179  GSM3664995  SRR8707618
# 180  GSM3664996  SRR8707619
# 181  GSM3664997  SRR8707620
# 182  GSM3049595  SRR6855536
#
#                                              GEO Title  \
# 0    mES HiChIP H3K27ac 25m biological replicate 1 ...
# 1    mES HiChIP H3K27ac 25m biological replicate 1 ...
# 2    mES HiChIP H3K27ac 25m biological replicate 2 ...
# 3    mES HiChIP H3K27ac 25m biological replicate 2 ...
# 4       mES HiChIP H3K27ac 500k biological replicate 1
# ..                                                 ...
# 178                                HiChIP YY1-PDS rep1
# 179                                HiChIP YY1-PDS rep2
# 180                             HiChIP YY1-TMPYP4 rep1
# 181                             HiChIP YY1-TMPYP4 rep2
# 182                                 HCT116-HiChIP-SMC1
#
#                         GEO Source  \
# 0    v6.5 embryonic stem cell line
# 1    v6.5 embryonic stem cell line
# 2    v6.5 embryonic stem cell line
# 3    v6.5 embryonic stem cell line
# 4    v6.5 embryonic stem cell line
# ..                             ...
# 178                293T YY1-TAPTAG
# 179                293T YY1-TAPTAG
# 180                293T YY1-TAPTAG
# 181                293T YY1-TAPTAG
# 182    Colorectal Cancer Cell Line
#
#                                        GEO Description      Organism  \
# 0    Protein-enriched long-range contact; mES_HiChI...  Mus musculus
# 1    Protein-enriched long-range contact; mES_HiChI...  Mus musculus
# 2    Protein-enriched long-range contact; mES_HiChI...  Mus musculus
# 3    Protein-enriched long-range contact; mES_HiChI...  Mus musculus
# 4    Protein-enriched long-range contact; mES_HiChI...  Mus musculus
# ..                                                 ...           ...
# 178  processed data file: HiChIP_PDS_Interaction_Ma...  Homo sapiens
# 179  processed data file: HiChIP_PDS_Interaction_Ma...  Homo sapiens
# 180  processed data file: HiChIP_TMP_Interaction_Ma...  Homo sapiens
# 181  processed data file: HiChIP_TMP_Interaction_Ma...  Homo sapiens
# 182                                                NaN  Homo sapiens
#
#     Number of Reads  ...  Download Status  HiCPro Status HiChIP Peaks Status  \
# 0       373,303,396  ...                1              1                   0
# 1       269,130,644  ...                1              1                   0
# 2       306,801,366  ...                1              1                   0
# 3       359,787,238  ...                1              1                   0
# 4       249,255,802  ...                1              1                   0
# ..              ...  ...              ...            ...                 ...
# 178        50913880  ...                0              0                   0
# 179        40894724  ...                0              0                   0
# 180        91431398  ...                0              0                   0
# 181        93121852  ...                0              0                   0
# 182        99930754  ...                0              0                   0
#
#     hichipper Status   OTHER Status  FitHiChIP Status  Operator  Priority  \
# 0                  0              0                 0       NaN       NaN
# 1                  0              0                 0       NaN       NaN
# 2                  0              0                 0       NaN       NaN
# 3                  0              0                 0       NaN       NaN
# 4                  0              0                 0       NaN       NaN
# ..               ...            ...               ...       ...       ...
# 178                0              0                 0       NaN       NaN
# 179                0              0                 0       NaN       NaN
# 180                0              0                 0       NaN       NaN
# 181                0              0                 0       NaN       NaN
# 182                0              0                 0       NaN       NaN
#
#      Cluster Path/Branch  Comments
# 0                    NaN       NaN
# 1                    NaN       NaN
# 2                    NaN       NaN
# 3                    NaN       NaN
# 4                    NaN       NaN
# ..                   ...       ...
# 178                  NaN       NaN
# 179                  NaN       NaN
# 180                  NaN       NaN
# 181                  NaN       NaN
# 182                  NaN       NaN
#
# [183 rows x 25 columns]

# %%
# extract those samples which are ready for processing
ready_df = df.loc[df['Start Processing'] == 1]

# extract only the columns needed
major_cols = ['Sample Name (as used in the server)',
 'GSE ID',
 'GSM ID',
 'SRR ID',
 'Organism',
 'Biological Replicate Serial No',
 'Technical Replicate Serial No',
 'ChIP-seq Pull Down',
 'Restriction Enzyme']
ready_df = ready_df[major_cols]

# %%
def parse_organism(string):
    new_words = []
    for word in string.split():
        new_words.append(word.capitalize())
    new_string = '_'.join(new_words)
    return(new_string)

ready_df.loc[:, 'Organism'] = ready_df.loc[:, 'Organism'].apply(parse_organism)

# %%
# getting the sample names
sample_names = []
for i, sr in ready_df.iterrows():
    sample_name = '{sample_name}.{gse_id}.{organism}.{antibody_target}.b{biological_rep}'
    sample_name = sample_name.format(sample_name=sr[0],
                                     gse_id=sr[1],
                                     organism=sr[4],
                                     antibody_target=sr[7], 
                                     biological_rep=sr[5])
    sample_names.append(sample_name)
ready_df.loc[:, 'sample_name'] = sample_names

# %%
# renaming the columns for easy computational use 
ready_df.columns = ['sample_name', 'gse_id', 'gsm_id', 'srr_id',
                    'organism', 'bio_rep', 'tech_rep', 'antibody_target',
                    'restriction_enzyme', 'std_sample_name']

# %%
# reorder the columns
reorder = ['std_sample_name',
             'gse_id',
             'gsm_id',
             'srr_id',
             'organism',
             'bio_rep',
             'tech_rep',
             'antibody_target',
             'restriction_enzyme',
             'sample_name']
ready_df = ready_df[reorder]

# %%
ready_df
# Out:
#                                       std_sample_name     gse_id      gsm_id  \
# 0     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b1  GSE101498  GSM2705031
# 1     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b1  GSE101498  GSM2705032
# 2     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b2  GSE101498  GSM2705033
# 3     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b2  GSE101498  GSM2705034
# 4    mES_500k_cells.GSE101498.Mus_Musculus.H3K27ac.b1  GSE101498  GSM2705035
# ..                                                ...        ...         ...
# 178            293T-PDS.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664994
# 179            293T-PDS.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664995
# 180         293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664996
# 181         293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664997
# 182              HCT116.GSE92881.Homo_Sapiens.SMC1.b1   GSE92881  GSM3049595
#
#          srr_id      organism  bio_rep  tech_rep antibody_target  \
# 0    SRR5831479  Mus_Musculus        1         1         H3K27ac
# 1    SRR5831480  Mus_Musculus        1         2         H3K27ac
# 2    SRR5831481  Mus_Musculus        2         1         H3K27ac
# 3    SRR5831482  Mus_Musculus        2         2         H3K27ac
# 4    SRR5831483  Mus_Musculus        1         1         H3K27ac
# ..          ...           ...      ...       ...             ...
# 178  SRR8707617  Homo_Sapiens        1         1             YY1
# 179  SRR8707618  Homo_Sapiens        1         2             YY1
# 180  SRR8707619  Homo_Sapiens        1         1             YY1
# 181  SRR8707620  Homo_Sapiens        1         2             YY1
# 182  SRR6855536  Homo_Sapiens        1         1            SMC1
#
#     restriction_enzyme     sample_name
# 0                 MboI   mES_25m_cells
# 1                 MboI   mES_25m_cells
# 2                 MboI   mES_25m_cells
# 3                 MboI   mES_25m_cells
# 4                 MboI  mES_500k_cells
# ..                 ...             ...
# 178            HindIII        293T-PDS
# 179            HindIII        293T-PDS
# 180            HindIII     293T-TMPYP4
# 181            HindIII     293T-TMPYP4
# 182               MboI          HCT116
#
# [132 rows x 10 columns]

# %%
header_output = '{}.with_header.tsv'.format(output_prefix)
ready_df.to_csv(header_output, header=True, index=False, sep='\t')

without_header_output = '{}.without_header.tsv'.format(output_prefix)
ready_df.to_csv(without_header_output, header=False, index=False, sep='\t')

# %%
df.shape
# Out:
# (183, 25)

# %%
ready_df
# Out:
#                                       std_sample_name     gse_id      gsm_id  \
# 0     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b1  GSE101498  GSM2705031
# 1     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b1  GSE101498  GSM2705032
# 2     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b2  GSE101498  GSM2705033
# 3     mES_25m_cells.GSE101498.Mus_Musculus.H3K27ac.b2  GSE101498  GSM2705034
# 4    mES_500k_cells.GSE101498.Mus_Musculus.H3K27ac.b1  GSE101498  GSM2705035
# ..                                                ...        ...         ...
# 178            293T-PDS.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664994
# 179            293T-PDS.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664995
# 180         293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664996
# 181         293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1  GSE128106  GSM3664997
# 182              HCT116.GSE92881.Homo_Sapiens.SMC1.b1   GSE92881  GSM3049595
#
#          srr_id      organism  bio_rep  tech_rep antibody_target  \
# 0    SRR5831479  Mus_Musculus        1         1         H3K27ac
# 1    SRR5831480  Mus_Musculus        1         2         H3K27ac
# 2    SRR5831481  Mus_Musculus        2         1         H3K27ac
# 3    SRR5831482  Mus_Musculus        2         2         H3K27ac
# 4    SRR5831483  Mus_Musculus        1         1         H3K27ac
# ..          ...           ...      ...       ...             ...
# 178  SRR8707617  Homo_Sapiens        1         1             YY1
# 179  SRR8707618  Homo_Sapiens        1         2             YY1
# 180  SRR8707619  Homo_Sapiens        1         1             YY1
# 181  SRR8707620  Homo_Sapiens        1         2             YY1
# 182  SRR6855536  Homo_Sapiens        1         1            SMC1
#
#     restriction_enzyme     sample_name
# 0                 MboI   mES_25m_cells
# 1                 MboI   mES_25m_cells
# 2                 MboI   mES_25m_cells
# 3                 MboI   mES_25m_cells
# 4                 MboI  mES_500k_cells
# ..                 ...             ...
# 178            HindIII        293T-PDS
# 179            HindIII        293T-PDS
# 180            HindIII     293T-TMPYP4
# 181            HindIII     293T-TMPYP4
# 182               MboI          HCT116
#
# [132 rows x 10 columns]

# %%
without_header_output
# Out:
# 'results/samplesheets/fastq/2022.04.09.16.57.fastq.samplesheet.without_header.tsv'
