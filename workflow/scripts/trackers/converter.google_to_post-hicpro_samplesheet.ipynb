# %% [markdown]
# ### Usage
#
# 1. Download the HiChIP Tracker to your personal clone of the `hichip-db-loop-calling` repo as a `.tsv` file and store in `results/samplesheets/post-hicpro` (create this folder if it does not exist). Name using the following format: `YYYY.MM.DD.HH.NN.post-hicpro.google-samplesheet.tsv`. Note: always make sure to use two digits for month (MM), day (DD), hour (HH) and minute (NN).<br>
#
# 2. Save this date into the tracker package under: `workflow/scripts/trackers/tracker/__init__.py`
#
# 3. Convert this Google based samplesheet into the post-hicpro samplesheet by running this Jupyter Notebook: `hichip-db-loop-calling/workflow/scripts/trackers/converter.google_to_post-hicpro_samplesheet`
#
# 4. Update the softlink for `current-post-hicpro-without-header.tsv` within `results/samplesheets/post-hicpro`:  by using `ln -s -r -f YYYY.MM.DD.HH.NN.post-hicpro.samplesheet.without_header.tsv current-post-hicpro-without-header.tsv` where HH is hour and NN is minute in military time
#
# 5. You are all set to run the FitHiChIP peak calling, FitHiChIP loop calling, and HiCCUPS scripts using the indicies in `current-post-hicpro-without-header.tsv` corresponding to the samples you want to run!

# %%
import os
import sys
import pandas as pd
import tracker
latest_date = tracker.post_hicpro_processing_dates[-1]
os.chdir('/mnt/bioadhoc-temp/Groups/vd-ay/kfetter/hichip-db-loop-calling/')

# %%
latest_date
# Out:
# '2023.04.04.13.39'

# %%
# setting input and output with jupyter notebook in context 
if 'ipykernel_launcher.py' in sys.argv[0]:
    input_fn = 'results/samplesheets/post-hicpro/{}.post-hicpro.google-samplesheet.tsv'.format(latest_date)
    output_prefix = 'results/samplesheets/post-hicpro/{}.post-hicpro.samplesheet'.format(latest_date)
else:
    input_fn = sys.argv[1]
    output_prefix = sys.argv[2]

# %%
# loading the samplesheet
df = pd.read_table(input_fn, skiprows=0)

# %%
df
# Out:
#     Sample Name (as used in the server) Cellosaurus ID                 Study  \
# 0                   3134_siCTRL_1hr_Dex      CVCL_H641  Rinaldi et al., 2022
# 1                  3134_siNIPBL_1hr_Dex      CVCL_H641  Rinaldi et al., 2022
# 2                               3134_WT      CVCL_H641  Rinaldi et al., 2022
# 3                                   3T3      CVCL_0594     Tsao et al., 2022
# 4                                   3T3      CVCL_0594     Tsao et al., 2022
# ..                                  ...            ...                   ...
# 241                          Treg_WTGFP            NaN  Ramirez et al., 2022
# 242                              Villus            NaN     Chen et al., 2021
# 243                              Villus            NaN     Chen et al., 2021
# 244                      Villus_Hnf4DKO            NaN     Chen et al., 2021
# 245                      Villus_Hnf4DKO            NaN     Chen et al., 2021
#
#         GSE ID      GSM ID       SRR ID                           GEO Title  \
# 0    GSE162617  GSM4955433  SRR13192949       siCTRL 1h Dex rep#1 GR HiCHIP
# 1    GSE162617  GSM4955434  SRR13192950      siNIPBL 1h Dex rep#1 GR HiCHIP
# 2    GSE162617  GSM4955432  SRR13192948            untreated rep1 GR HiChIP
# 3    GSE192387  GSM5746145  SRR17296607                     HiChIP_3T3_Batf
# 4    GSE192387  GSM5746148  SRR17296610                     HiChIP_3T3_CTCF
# ..         ...         ...          ...                                 ...
# 241  GSE189442  GSM5701997  SRR17021172              H3K27Ac.HiChIP.WTGFP#2
# 242  GSE148691  GSM4476739  SRR11548368       H3K4me3_HiChIP_WT_Villus_rep1
# 243  GSE148691  GSM4476740  SRR11548369       H3K4me3_HiChIP_WT_Villus_rep2
# 244  GSE148691  GSM4476743  SRR11548372  H3K4me3_HiChIP_Hnf4DKO_Villus_rep1
# 245  GSE148691  GSM4476744  SRR11548373  H3K4me3_HiChIP_Hnf4DKO_Villus_rep2
#
#                                             GEO Source  \
# 0    cell line derived from mouse mammary epithelia...
# 1    cell line derived from mouse mammary epithelia...
# 2    cell line derived from mouse mammary epithelia...
# 3                                  NIH/3T3 Fibroblasts
# 4                                  NIH/3T3 Fibroblasts
# ..                                                 ...
# 241                                             spleen
# 242                     WT adult duodenal villus cells
# 243                     WT adult duodenal villus cells
# 244                Hnf4DKO adult duodenal villus cells
# 245                Hnf4DKO adult duodenal villus cells
#
#                                        GEO Description      Organism  ...  \
# 0                                                  NaN  Mus musculus  ...
# 1                                                  NaN  Mus musculus  ...
# 2                                                  NaN  Mus musculus  ...
# 3    HiChIP with BATF antibody on NIH/3T3 fibroblas...  Mus musculus  ...
# 4    HiChIP with CTCF  antibody on NIH/3T3 fibroblasts  Mus musculus  ...
# ..                                                 ...           ...  ...
# 241                                                NaN  Mus musculus  ...
# 242  H3K4me3_HiChIP_WT_Villus_CombinedReplicates.in...  Mus musculus  ...
# 243  H3K4me3_HiChIP_WT_Villus_CombinedReplicates.in...  Mus musculus  ...
# 244  H3K4me3_HiChIP_Hnf4DKO_Villus_CombinedReplicat...  Mus musculus  ...
# 245  H3K4me3_HiChIP_Hnf4DKO_Villus_CombinedReplicat...  Mus musculus  ...
#
#     Download/HiC-Pro Operator  Chip-Seq Peaks Operator  \
# 0                        Kyra                      NaN
# 1                        Kyra                      NaN
# 2                        Kyra                      NaN
# 3                        Kyra                      NaN
# 4                        Kyra                      NaN
# ..                        ...                      ...
# 241                      Kyra                      NaN
# 242                      Kyra                      NaN
# 243                      Kyra                      NaN
# 244                      Kyra                      NaN
# 245                      Kyra                      NaN
#
#      HiChIP Peaks/Loops Operator Priority Cluster Path/Branch  Date Added  \
# 0                            NaN      NaN                 NaN   5/16/2022
# 1                            NaN      NaN                 NaN   5/16/2022
# 2                            NaN      NaN                 NaN   5/16/2022
# 3                            NaN      NaN                 NaN   5/16/2022
# 4                            NaN      NaN                 NaN   5/16/2022
# ..                           ...      ...                 ...         ...
# 241                          NaN      NaN                 NaN   5/16/2022
# 242                          NaN      NaN                 NaN   5/16/2022
# 243                          NaN      NaN                 NaN   5/16/2022
# 244                          NaN      NaN                 NaN   5/16/2022
# 245                          NaN      NaN                 NaN   5/16/2022
#
#      Cell Category Cell Type  Cell Line or Primary Comments
# 0              NaN       NaN                   NaN      NaN
# 1              NaN       NaN                   NaN      NaN
# 2              NaN       NaN                   NaN      NaN
# 3              NaN       NaN                   NaN      NaN
# 4              NaN       NaN                   NaN      NaN
# ..             ...       ...                   ...      ...
# 241            NaN       NaN                   NaN      NaN
# 242            NaN       NaN                   NaN      NaN
# 243            NaN       NaN                   NaN      NaN
# 244            NaN       NaN                   NaN      NaN
# 245            NaN       NaN                   NaN      NaN
#
# [246 rows x 56 columns]

# %%
# extract those samples which are ready for post-hicpro analyses and processing
ready_df = df.loc[(df['Download Status'] == 1)]

# extract only the columns needed
major_cols = ['Sample Name (as used in the server)', 'Cellosaurus ID',
 'GSE ID',
 'Organism',
 'Biological Replicate Serial No',
 'ChIP-seq Pull Down',
 'Restriction Enzyme']
ready_df = ready_df[major_cols]

# %%
ready_df
# Out:
#     Sample Name (as used in the server) Cellosaurus ID     GSE ID  \
# 0                   3134_siCTRL_1hr_Dex      CVCL_H641  GSE162617
# 1                  3134_siNIPBL_1hr_Dex      CVCL_H641  GSE162617
# 2                               3134_WT      CVCL_H641  GSE162617
# 3                                   3T3      CVCL_0594  GSE192387
# 4                                   3T3      CVCL_0594  GSE192387
# ..                                  ...            ...        ...
# 241                          Treg_WTGFP            NaN  GSE189442
# 242                              Villus            NaN  GSE148691
# 243                              Villus            NaN  GSE148691
# 244                      Villus_Hnf4DKO            NaN  GSE148691
# 245                      Villus_Hnf4DKO            NaN  GSE148691
#
#          Organism  Biological Replicate Serial No ChIP-seq Pull Down  \
# 0    Mus musculus                               1                 GR
# 1    Mus musculus                               1                 GR
# 2    Mus musculus                               1                 GR
# 3    Mus musculus                               1               BATF
# 4    Mus musculus                               1               CTCF
# ..            ...                             ...                ...
# 241  Mus musculus                               2            H3K27ac
# 242  Mus musculus                               1            H3K4me3
# 243  Mus musculus                               1            H3K4me3
# 244  Mus musculus                               1            H3K4me3
# 245  Mus musculus                               1            H3K4me3
#
#     Restriction Enzyme
# 0                 MboI
# 1                 MboI
# 2                 MboI
# 3                 MboI
# 4                 MboI
# ..                 ...
# 241               MboI
# 242               MboI
# 243               MboI
# 244               MboI
# 245               MboI
#
# [242 rows x 7 columns]

# %%
check = "init.hichip_sample.mm10.insert.tsv"
check_df = pd.read_table(check)
check_geoid = check_df["geo_id"].to_list()
my_geoid = ready_df["gse_id"].to_list()

# %%
len(check_geoid)
# Out:
# 234

# %%
len(my_geoid)
# Out:
# 242

# %%
check_dict = {}
my_dict = {}
for i in check_geoid:
    if i not in check_dict:
        check_dict[i] = 1
    else:
        check_dict[i] = check_dict[i] + 1
for i in my_geoid:
    if i not in my_dict:
        my_dict[i] = 1
    else:
        my_dict[i] = my_dict[i] + 1

# %%
check_dict
# Out:
# {'GSE101498': 10,
#  'GSE110898': 2,
#  'GSE112176': 4,
#  'GSE112717': 4,
#  'GSE113339': 37,
#  'GSE115524': 8,
#  'GSE121671': 2,
#  'GSE126362': 12,
#  'GSE135296': 2,
#  'GSE141113': 8,
#  'GSE141847': 10,
#  'GSE142004': 8,
#  'GSE145793': 4,
#  'GSE147919': 8,
#  'GSE148691': 8,
#  'GSE150536': 4,
#  'GSE150906': 2,
#  'GSE153884': 8,
#  'GSE157666': 3,
#  'GSE159629': 4,
#  'GSE160656': 13,
#  'GSE162617': 3,
#  'GSE166177': 6,
#  'GSE178344': 2,
#  'GSE189442': 14,
#  'GSE192387': 6,
#  'GSE193079': 6,
#  'GSE80820': 10,
#  'GSE99519': 26}

# %%
my_dict
# Out:
# {'GSE101498': 10,
#  'GSE110898': 2,
#  'GSE112176': 4,
#  'GSE112717': 4,
#  'GSE113339': 37,
#  'GSE115524': 12,
#  'GSE121671': 2,
#  'GSE126362': 12,
#  'GSE135296': 2,
#  'GSE141113': 8,
#  'GSE141847': 10,
#  'GSE142004': 8,
#  'GSE145793': 4,
#  'GSE147919': 8,
#  'GSE148691': 8,
#  'GSE150536': 4,
#  'GSE150906': 2,
#  'GSE153884': 8,
#  'GSE157666': 3,
#  'GSE159629': 4,
#  'GSE160656': 13,
#  'GSE162617': 3,
#  'GSE166177': 6,
#  'GSE178344': 2,
#  'GSE189442': 14,
#  'GSE192387': 6,
#  'GSE193079': 6,
#  'GSE80820': 14,
#  'GSE99519': 26}

# %%
# capitalizes organism
def parse_organism(string):
    new_words = []
    for word in string.split():
        new_words.append(word.capitalize())
    new_string = '_'.join(new_words)
    return(new_string)

ready_df.loc[:, 'Organism'] = ready_df.loc[:, 'Organism'].apply(parse_organism)

# %%
# getting the sample names
sample_names = []
for i, sr in ready_df.iterrows():
    sample_name = '{sample_name}.{gse_id}.{organism}.{antibody_target}.b{biological_rep}'
    sample_name = sample_name.format(sample_name=sr[0],
                                     gse_id=sr[2],
                                     organism=sr[3],
                                     antibody_target=sr[6], 
                                     biological_rep=sr[4])
    sample_names.append(sample_name)
ready_df.loc[:, 'sample_name'] = sample_names

# %%
# renaming the columns for easy computational use 
ready_df.columns = ['sample_name', 'cellosaurus_id', 'gse_id',
                    'organism', 'bio_rep', 'antibody_target',
                    'restriction_enzyme', 'std_sample_name']

# %%
# reorder the columns
reorder = ['std_sample_name',
             'cellosaurus_id',
             'gse_id',
             'organism',
             'bio_rep',
             'antibody_target',
             'restriction_enzyme',
             'sample_name']
ready_df = ready_df[reorder]
final_df = ready_df.drop_duplicates()

# %%
final_df
# Out:
#                                        std_sample_name cellosaurus_id  \
# 0    3134_siCTRL_1hr_Dex.GSE162617.Mus_Musculus.Mbo...      CVCL_H641
# 1    3134_siNIPBL_1hr_Dex.GSE162617.Mus_Musculus.Mb...      CVCL_H641
# 2               3134_WT.GSE162617.Mus_Musculus.MboI.b1      CVCL_H641
# 3                   3T3.GSE192387.Mus_Musculus.MboI.b1      CVCL_0594
# 4                   3T3.GSE192387.Mus_Musculus.MboI.b1      CVCL_0594
# ..                                                 ...            ...
# 239             Treg_WT.GSE112176.Mus_Musculus.MboI.b2            NaN
# 240          Treg_WTGFP.GSE189442.Mus_Musculus.MboI.b1            NaN
# 241          Treg_WTGFP.GSE189442.Mus_Musculus.MboI.b2            NaN
# 242              Villus.GSE148691.Mus_Musculus.MboI.b1            NaN
# 244      Villus_Hnf4DKO.GSE148691.Mus_Musculus.MboI.b1            NaN
#
#         gse_id      organism  bio_rep antibody_target restriction_enzyme  \
# 0    GSE162617  Mus_Musculus        1              GR               MboI
# 1    GSE162617  Mus_Musculus        1              GR               MboI
# 2    GSE162617  Mus_Musculus        1              GR               MboI
# 3    GSE192387  Mus_Musculus        1            BATF               MboI
# 4    GSE192387  Mus_Musculus        1            CTCF               MboI
# ..         ...           ...      ...             ...                ...
# 239  GSE112176  Mus_Musculus        2         H3K27ac               MboI
# 240  GSE189442  Mus_Musculus        1         H3K27ac               MboI
# 241  GSE189442  Mus_Musculus        2         H3K27ac               MboI
# 242  GSE148691  Mus_Musculus        1         H3K4me3               MboI
# 244  GSE148691  Mus_Musculus        1         H3K4me3               MboI
#
#               sample_name
# 0     3134_siCTRL_1hr_Dex
# 1    3134_siNIPBL_1hr_Dex
# 2                 3134_WT
# 3                     3T3
# 4                     3T3
# ..                    ...
# 239               Treg_WT
# 240            Treg_WTGFP
# 241            Treg_WTGFP
# 242                Villus
# 244        Villus_Hnf4DKO
#
# [194 rows x 8 columns]

# %%
header_output = '{}.with_header.tsv'.format(output_prefix)
final_df.to_csv(header_output, header=True, index=False, sep='\t')

# %%
without_header_output = '{}.without_header.tsv'.format(output_prefix)
final_df.to_csv(without_header_output, header=False, index=False, sep='\t')
