# %% [markdown]
# ### Usage
#
# 1. Download the HiChIP Tracker to your personal clone of the `hichip-db-loop-calling` repo as a `.tsv` file and store in `results/samplesheets/post-hicpro` (create this folder if it does not exist). Name using the following format: `YYYY.MM.DD.HH.NN.post-hicpro.google-samplesheet.tsv`. Note: always make sure to use two digits for month (MM), day (DD), hour (HH) and minute (NN).<br>
#
# 2. Save this date into the tracker package under: `workflow/scripts/trackers/tracker/__init__.py`
#
# 3. Convert this Google based samplesheet into the post-hicpro samplesheet by running this Jupyter Notebook: `hichip-db-loop-calling/workflow/scripts/trackers/converter.google_to_post-hicpro_samplesheet`
#
# 4. Update the softlink for `current-post-hicpro-without-header.tsv` within `results/samplesheets/post-hicpro`:  by using `ln -s -r -f YYYY.MM.DD.HH.NN.post-hicpro.samplesheet.without_header.tsv current-post-hicpro-without-header.tsv` where HH is hour and NN is minute in military time
#
# 5. You are all set to run the FitHiChIP peak calling, FitHiChIP loop calling, and HiCCUPS scripts using the indicies in `current-post-hicpro-without-header.tsv` corresponding to the samples you want to run!

# %%
import os
import sys
import pandas as pd
import tracker
latest_date = tracker.post_hicpro_processing_dates[-1]
os.chdir('/mnt/BioAdHoc/Groups/vd-ay/kfetter/hichip-db-loop-calling/')

# %%
latest_date
# Out:
# '2022.08.02.10.00'

# %%
# setting input and output with jupyter notebook in context 
if 'ipykernel_launcher.py' in sys.argv[0]:
    input_fn = 'results/samplesheets/post-hicpro/{}.post-hicpro.google-samplesheet.tsv'.format(latest_date)
    output_prefix = 'results/samplesheets/post-hicpro/{}.post-hicpro.samplesheet'.format(latest_date)
else:
    input_fn = sys.argv[1]
    output_prefix = sys.argv[2]

# %%
# loading the samplesheet
df = pd.read_table(input_fn, skiprows=0)

# %%
df
# Out:
#     Sample Name (as used in the server)              Study     GSE ID  \
# 0                                  293T    Li et al., 2020  GSE128106
# 1                                  293T    Li et al., 2020  GSE128106
# 2                                  293T    Li et al., 2020  GSE128106
# 3                                  293T    Li et al., 2020  GSE128106
# 4                              293T-PDS    Li et al., 2020  GSE128106
# ..                                  ...                ...        ...
# 480                        VCAP-DHT-2hr   Guo et al., 2021  GSE157107
# 481                        VCaP-DMSO-4h  Xiao et al., 2022  GSE171591
# 482                        VCaP-DMSO-4h  Xiao et al., 2022  GSE171591
# 483                        VCaP-DMSO-4h  Xiao et al., 2022  GSE171591
# 484                            VCAP-Veh   Guo et al., 2021  GSE157107
#
#          GSM ID       SRR ID                          GEO Title  \
# 0    GSM3664990   SRR8707613                    HiChIP YY1 rep1
# 1    GSM3664991   SRR8707614                    HiChIP YY1 rep2
# 2    GSM3664992   SRR8707615                    HiChIP YY1 rep3
# 3    GSM3664993   SRR8707616                    HiChIP YY1 rep4
# 4    GSM3664994   SRR8707617                HiChIP YY1-PDS rep1
# ..          ...          ...                                ...
# 480  GSM4782223  SRR12643179        VCAP_H3K27ac_HiChIP_DHT_2hr
# 481  GSM5229035  SRR14159848  VCaP_DMSO_4h_H3K4me3 (HiChIP-seq)
# 482  GSM5229037  SRR14159850  VCaP_DMSO_4h_H3K27Ac (HiChIP-seq)
# 483  GSM5229039  SRR14159852     VCaP_DMSO_4h_CTCF (HiChIP-seq)
# 484  GSM4782222  SRR12643178            VCAP_H3K27ac_HiChIP_Veh
#
#           GEO Source                                    GEO Description  \
# 0    293T YY1-TAPTAG  processed data file: HiChIP_Kin_Interaction_Ma...
# 1    293T YY1-TAPTAG  processed data file: HiChIP_Kin_Interaction_Ma...
# 2    293T YY1-TAPTAG  processed data file: HiChIP_Kin_Interaction_Ma...
# 3    293T YY1-TAPTAG  processed data file: HiChIP_Kin_Interaction_Ma...
# 4    293T YY1-TAPTAG  processed data file: HiChIP_PDS_Interaction_Ma...
# ..               ...                                                ...
# 480       VCaP cells                       H3K27ac HiChIP in VCaP cells
# 481             VCaP                                                NaN
# 482             VCaP                                                NaN
# 483             VCaP                                                NaN
# 484       VCaP cells                       H3K27ac HiChIP in VCaP cells
#
#          Organism Number of Reads  ...  FitHiChIP FitHiChIP L25 Loops Status  \
# 0    Homo sapiens     220,406,226  ...                                     0
# 1    Homo sapiens     234,171,286  ...                                     0
# 2    Homo sapiens      21,901,000  ...                                     0
# 3    Homo sapiens      18,913,262  ...                                     0
# 4    Homo sapiens      50,913,880  ...                                     0
# ..            ...             ...  ...                                   ...
# 480  Homo sapiens       7,398,342  ...                                     0
# 481  Homo sapiens     251,548,098  ...                                    -1
# 482  Homo sapiens     177,992,192  ...                                    -1
# 483  Homo sapiens     179,864,588  ...                                    -1
# 484  Homo sapiens       8,695,872  ...                                     0
#
#      Chr1 HiCCUPS 5,10,25 Loops Status All Chrs HiCCUPS 5,10,25 Loops Status  \
# 0                                    1                                    -1
# 1                                    1                                    -1
# 2                                    1                                    -1
# 3                                    1                                    -1
# 4                                    1                                    -1
# ..                                 ...                                   ...
# 480                                  1                                    -1
# 481                                  1                                    -1
# 482                                  1                                    -1
# 483                                  1                                     1
# 484                                  1                                    -1
#
#     Download/HiC-Pro Operator  Chip-Seq Peaks Operator  \
# 0                     Joaquin                   Nikhil
# 1                     Joaquin                   Nikhil
# 2                     Joaquin                   Nikhil
# 3                     Joaquin                   Nikhil
# 4                     Joaquin                   Nikhil
# ..                        ...                      ...
# 480                   Joaquin                   Nikhil
# 481                   Joaquin                      NaN
# 482                   Joaquin                      NaN
# 483                   Joaquin                      NaN
# 484                   Joaquin                   Nikhil
#
#      HiChIP Peaks/Loops Operator Priority Cluster Path/Branch     Date Added  \
# 0                           Kyra      NaN                 NaN  pre-5/16/2022
# 1                           Kyra      NaN                 NaN  pre-5/16/2022
# 2                           Kyra      NaN                 NaN  pre-5/16/2022
# 3                           Kyra      NaN                 NaN  pre-5/16/2022
# 4                           Kyra      NaN                 NaN  pre-5/16/2022
# ..                           ...      ...                 ...            ...
# 480                         Kyra      NaN                 NaN      5/16/2022
# 481                         Kyra      NaN                 NaN      5/16/2022
# 482                         Kyra      NaN                 NaN      5/16/2022
# 483                         Kyra      NaN                 NaN      5/16/2022
# 484                         Kyra      NaN                 NaN      5/16/2022
#
#     Comments
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 480      NaN
# 481      NaN
# 482      NaN
# 483      NaN
# 484      NaN
#
# [485 rows x 52 columns]

# %%
# extract those samples which are ready for post-hicpro analyses and processing
ready_df = df.loc[(df['Priority'] == 'Immune')]

# extract only the columns needed
major_cols = ['Sample Name (as used in the server)',
 'GSE ID',
 'Organism',
 'Biological Replicate Serial No',
 'ChIP-seq Pull Down',
 'Restriction Enzyme']
ready_df = ready_df[major_cols]

# %%
ready_df
# Out:
#     Sample Name (as used in the server)     GSE ID      Organism  \
# 98                              GM12878  GSE101498  Homo sapiens
# 99                              GM12878  GSE101498  Homo sapiens
# 100                             GM12878  GSE115524  Homo sapiens
# 101                             GM12878  GSE115524  Homo sapiens
# 102                             GM12878   GSE80820  Homo sapiens
# 103                             GM12878   GSE80820  Homo sapiens
# 104                             GM12878   GSE80820  Homo sapiens
# 105                             GM12878   GSE80820  Homo sapiens
# 121                                  H9  GSE105028  Homo sapiens
# 122                                  H9  GSE105028  Homo sapiens
# 123                                  H9  GSE105028  Homo sapiens
# 124                                  H9  GSE105028  Homo sapiens
# 125                                  H9  GSE105028  Homo sapiens
# 126                                  H9  GSE105028  Homo sapiens
# 127                                  H9  GSE105028  Homo sapiens
# 128                                  H9  GSE105028  Homo sapiens
# 129                                  H9  GSE105028  Homo sapiens
# 130                                  H9  GSE105028  Homo sapiens
# 131                                  H9  GSE105028  Homo sapiens
# 132                                  H9  GSE105028  Homo sapiens
# 133                                  H9  GSE105028  Homo sapiens
# 134                                  H9  GSE105028  Homo sapiens
# 135                                  H9  GSE105028  Homo sapiens
# 161                                HARA  GSE147854  Homo sapiens
# 280                           lgs000379  GSE116193  Homo sapiens
# 281                           lgs000379  GSE116193  Homo sapiens
# 282                           lgs101645  GSE116193  Homo sapiens
# 283                           lgs101645  GSE116193  Homo sapiens
# 284                           lgs102580  GSE116193  Homo sapiens
# 285                           lgs102580  GSE116193  Homo sapiens
# 286                           lgs102943  GSE116193  Homo sapiens
# 287                           lgs102943  GSE116193  Homo sapiens
# 288                           lgs301283  GSE116193  Homo sapiens
# 289                           lgs301283  GSE116193  Homo sapiens
# 290                           lgs301315  GSE116193  Homo sapiens
# 291                           lgs301315  GSE116193  Homo sapiens
# 313                                MyLa  GSE101498  Homo sapiens
# 314                                MyLa  GSE101498  Homo sapiens
# 315                                MyLa  GSE151193  Homo sapiens
# 316                                MyLa  GSE151193  Homo sapiens
# 317                                MyLa  GSE151193  Homo sapiens
# 320                        Naive_Tcells  GSE101498  Homo sapiens
# 321                        Naive_Tcells  GSE101498  Homo sapiens
# 322                        Naive_Tcells  GSE101498  Homo sapiens
# 323                        Naive_Tcells  GSE101498  Homo sapiens
# 324                        Naive_Tcells  GSE101498  Homo sapiens
# 325                        Naive_Tcells  GSE101498  Homo sapiens
# 326                        Naive_Tcells  GSE101498  Homo sapiens
# 444                                Th17  GSE101498  Homo sapiens
# 445                                Th17  GSE101498  Homo sapiens
# 446                                Th17  GSE101498  Homo sapiens
# 447                                Th17  GSE101498  Homo sapiens
# 472                                Treg  GSE101498  Homo sapiens
# 473                                Treg  GSE101498  Homo sapiens
# 474                                Treg  GSE101498  Homo sapiens
#
#      Biological Replicate Serial No ChIP-seq Pull Down Restriction Enzyme
# 98                                1            H3K27ac               MboI
# 99                                2            H3K27ac               MboI
# 100                               1               CTCF               MboI
# 101                               2               CTCF               MboI
# 102                               1              SMC1A               MboI
# 103                               1              SMC1A               MboI
# 104                               2              SMC1A               MboI
# 105                               2              SMC1A               MboI
# 121                               1              Rad21              DpnII
# 122                               1              Rad21              DpnII
# 123                               1              Rad21              DpnII
# 124                               1              Rad21              DpnII
# 125                               1               CTCF              DpnII
# 126                               1               CTCF              DpnII
# 127                               1               CTCF              DpnII
# 128                               1               OCT4              DpnII
# 129                               1               OCT4              DpnII
# 130                               1              NANOG              DpnII
# 131                               1              NANOG              DpnII
# 132                               1               KLF4              DpnII
# 133                               1               KLF4              DpnII
# 134                               1            H3K4me1              DpnII
# 135                               1            H3K4me1              DpnII
# 161                               1            H3K27ac               MboI
# 280                               1            H3K27ac               MboI
# 281                               1               CTCF               MboI
# 282                               1            H3K27ac               MboI
# 283                               1               CTCF               MboI
# 284                               1            H3K27ac               MboI
# 285                               1               CTCF               MboI
# 286                               1            H3K27ac               MboI
# 287                               1               CTCF               MboI
# 288                               1            H3K27ac               MboI
# 289                               1               CTCF               MboI
# 290                               1            H3K27ac               MboI
# 291                               1               CTCF               MboI
# 313                               1            H3K27ac               MboI
# 314                               2            H3K27ac               MboI
# 315                               1            H3K27ac               MboI
# 316                               1            H3K27ac               MboI
# 317                               1            H3K27ac               MboI
# 320                               1            H3K27ac               MboI
# 321                               2            H3K27ac               MboI
# 322                               2            H3K27ac               MboI
# 323                               3            H3K27ac               MboI
# 324                               3            H3K27ac               MboI
# 325                               1               CTCF               MboI
# 326                               2               CTCF               MboI
# 444                               1            H3K27ac               MboI
# 445                               1            H3K27ac               MboI
# 446                               2            H3K27ac               MboI
# 447                               3            H3K27ac               MboI
# 472                               1            H3K27ac               MboI
# 473                               2            H3K27ac               MboI
# 474                               3            H3K27ac               MboI

# %%
# capitalizes organism
def parse_organism(string):
    new_words = []
    for word in string.split():
        new_words.append(word.capitalize())
    new_string = '_'.join(new_words)
    return(new_string)

ready_df.loc[:, 'Organism'] = ready_df.loc[:, 'Organism'].apply(parse_organism)

# %%
# getting the sample names
sample_names = []
for i, sr in ready_df.iterrows():
    sample_name = '{sample_name}.{gse_id}.{organism}.{antibody_target}.b{biological_rep}'
    sample_name = sample_name.format(sample_name=sr[0],
                                     gse_id=sr[1],
                                     organism=sr[2],
                                     antibody_target=sr[4], 
                                     biological_rep=sr[3])
    sample_names.append(sample_name)
ready_df.loc[:, 'sample_name'] = sample_names

# %%
# renaming the columns for easy computational use 
ready_df.columns = ['sample_name', 'gse_id',
                    'organism', 'bio_rep', 'antibody_target',
                    'restriction_enzyme', 'std_sample_name']

# %%
# reorder the columns
reorder = ['std_sample_name',
             'gse_id',
             'organism',
             'bio_rep',
             'antibody_target',
             'restriction_enzyme',
             'sample_name']
ready_df = ready_df[reorder]
final_df = ready_df.drop_duplicates()

# %%
final_df
# Out:
#                                     std_sample_name     gse_id      organism  \
# 98        GM12878.GSE101498.Homo_Sapiens.H3K27ac.b1  GSE101498  Homo_Sapiens
# 99        GM12878.GSE101498.Homo_Sapiens.H3K27ac.b2  GSE101498  Homo_Sapiens
# 100          GM12878.GSE115524.Homo_Sapiens.CTCF.b1  GSE115524  Homo_Sapiens
# 101          GM12878.GSE115524.Homo_Sapiens.CTCF.b2  GSE115524  Homo_Sapiens
# 102          GM12878.GSE80820.Homo_Sapiens.SMC1A.b1   GSE80820  Homo_Sapiens
# 104          GM12878.GSE80820.Homo_Sapiens.SMC1A.b2   GSE80820  Homo_Sapiens
# 121              H9.GSE105028.Homo_Sapiens.Rad21.b1  GSE105028  Homo_Sapiens
# 125               H9.GSE105028.Homo_Sapiens.CTCF.b1  GSE105028  Homo_Sapiens
# 128               H9.GSE105028.Homo_Sapiens.OCT4.b1  GSE105028  Homo_Sapiens
# 130              H9.GSE105028.Homo_Sapiens.NANOG.b1  GSE105028  Homo_Sapiens
# 132               H9.GSE105028.Homo_Sapiens.KLF4.b1  GSE105028  Homo_Sapiens
# 134            H9.GSE105028.Homo_Sapiens.H3K4me1.b1  GSE105028  Homo_Sapiens
# 161          HARA.GSE147854.Homo_Sapiens.H3K27ac.b1  GSE147854  Homo_Sapiens
# 280     lgs000379.GSE116193.Homo_Sapiens.H3K27ac.b1  GSE116193  Homo_Sapiens
# 281        lgs000379.GSE116193.Homo_Sapiens.CTCF.b1  GSE116193  Homo_Sapiens
# 282     lgs101645.GSE116193.Homo_Sapiens.H3K27ac.b1  GSE116193  Homo_Sapiens
# 283        lgs101645.GSE116193.Homo_Sapiens.CTCF.b1  GSE116193  Homo_Sapiens
# 284     lgs102580.GSE116193.Homo_Sapiens.H3K27ac.b1  GSE116193  Homo_Sapiens
# 285        lgs102580.GSE116193.Homo_Sapiens.CTCF.b1  GSE116193  Homo_Sapiens
# 286     lgs102943.GSE116193.Homo_Sapiens.H3K27ac.b1  GSE116193  Homo_Sapiens
# 287        lgs102943.GSE116193.Homo_Sapiens.CTCF.b1  GSE116193  Homo_Sapiens
# 288     lgs301283.GSE116193.Homo_Sapiens.H3K27ac.b1  GSE116193  Homo_Sapiens
# 289        lgs301283.GSE116193.Homo_Sapiens.CTCF.b1  GSE116193  Homo_Sapiens
# 290     lgs301315.GSE116193.Homo_Sapiens.H3K27ac.b1  GSE116193  Homo_Sapiens
# 291        lgs301315.GSE116193.Homo_Sapiens.CTCF.b1  GSE116193  Homo_Sapiens
# 313          MyLa.GSE101498.Homo_Sapiens.H3K27ac.b1  GSE101498  Homo_Sapiens
# 314          MyLa.GSE101498.Homo_Sapiens.H3K27ac.b2  GSE101498  Homo_Sapiens
# 315          MyLa.GSE151193.Homo_Sapiens.H3K27ac.b1  GSE151193  Homo_Sapiens
# 320  Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b1  GSE101498  Homo_Sapiens
# 321  Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b2  GSE101498  Homo_Sapiens
# 323  Naive_Tcells.GSE101498.Homo_Sapiens.H3K27ac.b3  GSE101498  Homo_Sapiens
# 325     Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b1  GSE101498  Homo_Sapiens
# 326     Naive_Tcells.GSE101498.Homo_Sapiens.CTCF.b2  GSE101498  Homo_Sapiens
# 444          Th17.GSE101498.Homo_Sapiens.H3K27ac.b1  GSE101498  Homo_Sapiens
# 446          Th17.GSE101498.Homo_Sapiens.H3K27ac.b2  GSE101498  Homo_Sapiens
# 447          Th17.GSE101498.Homo_Sapiens.H3K27ac.b3  GSE101498  Homo_Sapiens
# 472          Treg.GSE101498.Homo_Sapiens.H3K27ac.b1  GSE101498  Homo_Sapiens
# 473          Treg.GSE101498.Homo_Sapiens.H3K27ac.b2  GSE101498  Homo_Sapiens
# 474          Treg.GSE101498.Homo_Sapiens.H3K27ac.b3  GSE101498  Homo_Sapiens
#
#      bio_rep antibody_target restriction_enzyme   sample_name
# 98         1         H3K27ac               MboI       GM12878
# 99         2         H3K27ac               MboI       GM12878
# 100        1            CTCF               MboI       GM12878
# 101        2            CTCF               MboI       GM12878
# 102        1           SMC1A               MboI       GM12878
# 104        2           SMC1A               MboI       GM12878
# 121        1           Rad21              DpnII            H9
# 125        1            CTCF              DpnII            H9
# 128        1            OCT4              DpnII            H9
# 130        1           NANOG              DpnII            H9
# 132        1            KLF4              DpnII            H9
# 134        1         H3K4me1              DpnII            H9
# 161        1         H3K27ac               MboI          HARA
# 280        1         H3K27ac               MboI     lgs000379
# 281        1            CTCF               MboI     lgs000379
# 282        1         H3K27ac               MboI     lgs101645
# 283        1            CTCF               MboI     lgs101645
# 284        1         H3K27ac               MboI     lgs102580
# 285        1            CTCF               MboI     lgs102580
# 286        1         H3K27ac               MboI     lgs102943
# 287        1            CTCF               MboI     lgs102943
# 288        1         H3K27ac               MboI     lgs301283
# 289        1            CTCF               MboI     lgs301283
# 290        1         H3K27ac               MboI     lgs301315
# 291        1            CTCF               MboI     lgs301315
# 313        1         H3K27ac               MboI          MyLa
# 314        2         H3K27ac               MboI          MyLa
# 315        1         H3K27ac               MboI          MyLa
# 320        1         H3K27ac               MboI  Naive_Tcells
# 321        2         H3K27ac               MboI  Naive_Tcells
# 323        3         H3K27ac               MboI  Naive_Tcells
# 325        1            CTCF               MboI  Naive_Tcells
# 326        2            CTCF               MboI  Naive_Tcells
# 444        1         H3K27ac               MboI          Th17
# 446        2         H3K27ac               MboI          Th17
# 447        3         H3K27ac               MboI          Th17
# 472        1         H3K27ac               MboI          Treg
# 473        2         H3K27ac               MboI          Treg
# 474        3         H3K27ac               MboI          Treg

# %%
header_output = '{}.with_header.tsv'.format(output_prefix)
final_df.to_csv(header_output, header=True, index=False, sep='\t')

# %%
without_header_output = '{}.without_header.tsv'.format(output_prefix)
final_df.to_csv(without_header_output, header=False, index=False, sep='\t')
