# %%
import pandas as pd
import csv
import string
import glob
import os
import subprocess

# %%
# how many reads
# whether there was a control or not and whether it is used in peak calling
# how many peaks at what setting and threshold

# %%
def generate_summary_df(path):
    samples = []
    with open(path,'r') as file:

        #reader = csv.reader(file, delimiter='\t')
        #next(reader, None)
        reader = csv.DictReader(file, delimiter='\t')
        for line in reader:
            sample_info = []
            
            # if there is no sample name, skip this line
            if not line['Sample Name']:
                continue
            # If there was an issue in peak calling, skip this line
            if line["Ran peak calling"]=="-1":
                continue

            ##### CONSTRUCT THE SAMPLE NAME ######

            name = line['Sample Name']
            gse = line['GSE ID of Corresponding HiChIP Data']

            organism = line['Organism']
            organism = string.capwords(organism).replace(" ", "_")

            target_of_antibody = line['ChIP-seq Pull Down']
            if (target_of_antibody=="N/A"):
                continue
            
            replicate = line['Replicate Serial No']

            sample_name = name + "." + gse + "." + organism + "." + target_of_antibody + ".b" + replicate

            ###########

            # determine whether a control is present
            control_info = "no control for this sample"
            if line['Control GSM(s)']!="N/A":
                control_info = "control present and used in peak calling"

            
            # determine peak sizes and settings
            narrowpeak1 = "peak calling not completed"
            narrowpeak2 = "peak calling not completed"

            idrpeak1 = "peak calling not completed"
            idrpeak2 = "peak calling not completed"

            # check for merged replicates number of peaks
            if line['Merged replicates (if there are replicates)']=="1":
                merged_sample_name = sample_name[:-1] + "1"
                idrpeakpath = "../../../results/peaks/merged_chipline/" + merged_sample_name
                idrpeakpath1 = idrpeakpath + "/FINAL_IDR_Peaks_FDR0.1.txt"
                idrpeakpath2 = idrpeakpath + "/FINAL_IDR_Peaks_FDR0.05.txt"

                if os.path.exists(idrpeakpath):
                    idrpeak1 = sum(1 for line in open(idrpeakpath1))
                    idrpeak2 = sum(1 for line in open(idrpeakpath2))
                else:
                    idrpeak1 = "N/A"
                    idrpeak2 = "N/A"
            
            # check for peaks per replicate
            if line['Ran peak calling']=="1":
                narrowpeakpath = "../../../results/peaks/chipline/" + sample_name + "/MACS2_Ext*/"
                narrowpeakpath1 = narrowpeakpath + sample_name + ".macs2_peaks.narrowPeak_Q0.05filt"
                narrowpeakpath2 = narrowpeakpath + sample_name + ".macs2_peaks.narrowPeak_Q0.01filt"

                if len(glob.glob(narrowpeakpath1))==1:
                    narrowpeak1 = sum(1 for line in open(glob.glob(narrowpeakpath1)[0]))
                else:
                    narrowpeak1 = "error in peak calling"

                
                if len(glob.glob(narrowpeakpath2))==1:
                    narrowpeak2 = sum(1 for line in open(glob.glob(narrowpeakpath2)[0]))
                else:
                    narrowpeak2 = "error in peak calling"

            # include number of reads in the table
            num_reads = line['Number of Reads']

            sample_info = [sample_name, num_reads, control_info, narrowpeak1, narrowpeak2, idrpeak1, idrpeak2]
            samples.append(sample_info)
    
    df = pd.DataFrame(samples)
    return df

# %%
human_path = "../../../results/samplesheets/fastq/chipseq_human_tracker.tsv"
mouse_path = "../../../results/samplesheets/fastq/chipseq_mouse_tracker.tsv"

table = []
mouse_df = generate_summary_df(mouse_path)
human_df = generate_summary_df(human_path)

df = pd.concat([mouse_df, human_df])

columns = ["Sample Name", "Number of Reads", "Control Used?"]
columns.extend(["Narrow peaks with Q-value threshold of 0.05", "Narrow peaks with Q-value threshold of 0.01"])
columns.extend(["IDR peaks with respect to FDR 0.1", "IDR peaks with respect to FDR 0.05"])
df.columns = columns

# reset the row count
df = df.reset_index(drop=True)
df.index += 2

# display(df)

# samples = pd.concat([human_samples, mouse_samples])
# samples = samples.dropna(how='all', subset=['Sample Name'])
# samples = samples.reset_index(drop=True)

# display(samples)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#                                            Sample Name Number of Reads  \
# 2                 EryP.GSE112717.Mus_Musculus.Gata1.b1        99227512
# 3                 EryD.GSE112717.Mus_Musculus.Gata1.b1       101386530
# 4       AML12_shCtrl.GSE141113.Mus_Musculus.H3K9me3.b1       179731362
# 5       AML12_shCtrl.GSE141113.Mus_Musculus.H3K9me3.b2       339993774
# 6       AML12_shSafb.GSE141113.Mus_Musculus.H3K9me3.b1       121054242
# 7       AML12_shSafb.GSE141113.Mus_Musculus.H3K9me3.b2       247115720
# 8            MLL-AF9.GSE110898.Mus_Musculus.H3K27ac.b1        20734550
# 9      MLL-AF9-LSD1i.GSE110898.Mus_Musculus.H3K27ac.b1        22986018
# 10         BL6_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1       105018728
# 11         BL6_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2       105890154
# 12       BL6_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b1        62270978
# 13       BL6_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b2        55138540
# 14          F1_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1       102621806
# 15          F1_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2       110390090
# 16         NOD_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1        94585932
# 17         NOD_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2        90241994
# 18       NOD_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b1        74679072
# 19       NOD_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b2        64778236
# 20         Erythroid_0hr.GSE142004.Mus_Musculus.YY1.b1       179364760
# 21         Erythroid_0hr.GSE142004.Mus_Musculus.YY1.b2       179364760
# 22         Erythroid_1hr.GSE142004.Mus_Musculus.YY1.b1       158824840
# 23         Erythroid_1hr.GSE142004.Mus_Musculus.YY1.b2       158824840
# 24              mESC_WT.GSE147919.Mus_Musculus.RYBP.b1        63161940
# 25       BMDM_24hIL4.GSE159629.Mus_Musculus.H3K4me3.b1       191030280
# 26       BMDM_24hIL4.GSE159629.Mus_Musculus.H3K4me3.b2       233260738
# 27        BMDM_Basal.GSE159629.Mus_Musculus.H3K4me3.b1       352599370
# 28        BMDM_Basal.GSE159629.Mus_Musculus.H3K4me3.b2       265388266
# 29            3T3_Norm.GSE178344.Mus_Musculus.SMC1A.b1       101455152
# 30            3T3_TCF1.GSE178344.Mus_Musculus.SMC1A.b1        52934182
# 31               HK2.GSE147646.Homo_Sapiens.H3K27ac.b1     114,039,394
# 32               HK2.GSE147646.Homo_Sapiens.H3K27ac.b2      95,768,718
# 33               BC3.GSE136090.Homo_Sapiens.H3K27ac.b1       9,064,714
# 34               BC3.GSE136090.Homo_Sapiens.H3K27ac.b2       8,186,810
# 35             BCBL1.GSE136090.Homo_Sapiens.H3K27ac.b1      48,917,134
# 36             BCBL1.GSE136090.Homo_Sapiens.H3K27ac.b2      31,648,359
# 37               BC1.GSE136090.Homo_Sapiens.H3K27ac.b1       8,856,042
# 38               BC1.GSE136090.Homo_Sapiens.H3K27ac.b2      11,450,703
# 39               JSC.GSE136090.Homo_Sapiens.H3K27ac.b1      13,101,230
# 40               JSC.GSE136090.Homo_Sapiens.H3K27ac.b2       9,173,204
# 41         lgs301283.GSE116193.Homo_Sapiens.H3K27ac.b1     186,275,286
# 42         lgs101645.GSE116193.Homo_Sapiens.H3K27ac.b1     142,818,628
# 43         lgs102580.GSE116193.Homo_Sapiens.H3K27ac.b1     184,922,026
# 44         lgs301315.GSE116193.Homo_Sapiens.H3K27ac.b1     109,088,684
# 45         lgs102943.GSE116193.Homo_Sapiens.H3K27ac.b1     146,065,550
# 46         lgs000379.GSE116193.Homo_Sapiens.H3K27ac.b1     146,178,102
# 47                  H9.GSE105028.Homo_Sapiens.Rad21.b1        36016390
# 48                  H9.GSE105028.Homo_Sapiens.Rad21.b2        80882260
# 49               H9-HS.GSE105028.Homo_Sapiens.Rad21.b1      36,017,108
# 50               H9-HS.GSE105028.Homo_Sapiens.Rad21.b2        90532406
# 51                   H9.GSE105028.Homo_Sapiens.CTCF.b1        29223008
# 52                H9-HS.GSE105028.Homo_Sapiens.CTCF.b1        56978264
# 53                   H9.GSE105028.Homo_Sapiens.OCT4.b1        82848772
# 54                H9-HS.GSE105028.Homo_Sapiens.OCT4.b1        68495366
# 55                  H9.GSE105028.Homo_Sapiens.NANOG.b1        69443112
# 56               H9-HS.GSE105028.Homo_Sapiens.NANOG.b1        69689862
# 57                   H9.GSE105028.Homo_Sapiens.KLF4.b1        50233478
# 58                H9-HS.GSE105028.Homo_Sapiens.KLF4.b1        93849478
# 59                H9.GSE105028.Homo_Sapiens.H3K4me1.b1        54109020
# 60             H9-HS.GSE105028.Homo_Sapiens.H3K4me1.b1        51838618
# 61   HCT116-AuxinNeg.GSE179544.Homo_Sapiens.RNA-Pol...        72242674
# 62   HCT116-AuxinNeg.GSE179544.Homo_Sapiens.RNA-Pol...        69268810
# 63   HCT116-AuxinPos.GSE179544.Homo_Sapiens.RNA-Pol...        75780914
# 64   HCT116-AuxinPos.GSE179544.Homo_Sapiens.RNA-Pol...        68680726
# 65                  293T.GSE128106.Homo_Sapiens.YY1.b1       220406226
# 66                  293T.GSE128106.Homo_Sapiens.YY1.b2       234171286
# 67              293T-PDS.GSE128106.Homo_Sapiens.YY1.b1        50913880
# 68              293T-PDS.GSE128106.Homo_Sapiens.YY1.b2        40894724
# 69           293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b1        91431398
# 70           293T-TMPYP4.GSE128106.Homo_Sapiens.YY1.b2        93121852
# 71      Hela-S3-Control.GSE108869.Homo_Sapiens.CTCF.b1       131047790
# 72           Hela-S3-OE.GSE108869.Homo_Sapiens.CTCF.b1       120841808
# 73          OCI-AML3-WT.GSE111537.Homo_Sapiens.CTCF.b1        80285166
# 74   OCI-AML3-DeltaSTAG2.GSE111537.Homo_Sapiens.CTC...       133733004
# 75             Nalm6.GSE115492.Homo_Sapiens.H3K27ac.b1       192321052
# 76            STAG2-WT.GSE116495.Homo_Sapiens.SMC1A.b1       118318418
# 77            STAG2-KO.GSE116495.Homo_Sapiens.SMC1A.b1       189215394
# 78            MB157-WT.GSE116869.Homo_Sapiens.SMC1A.b1       188442910
# 79               DEX.GSE117888.Homo_Sapiens.H3K27ac.b1        77534828
# 80               CTL.GSE117888.Homo_Sapiens.H3K27ac.b1        75006510
# 81        HUDEP-2-WT.GSE131054.Homo_Sapiens.H3K27ac.b1       121485884
# 82        HUDEP-2-WT.GSE131054.Homo_Sapiens.H3K27ac.b2        97628538
# 83      HUDEP-2-Mut1.GSE131054.Homo_Sapiens.H3K27ac.b1        43908586
# 84      Erythroblast.GSE131054.Homo_Sapiens.H3K27ac.b1        66743794
# 85      Erythroblast.GSE131054.Homo_Sapiens.H3K27ac.b2        64692898
# 86       NSD2-High-NTKO.GSE131651.Homo_Sapiens.CTCF.b1        51059744
# 87       NSD2-High-NTKO.GSE131651.Homo_Sapiens.CTCF.b2        72083674
# 88       NSD2-High-NTKO.GSE131651.Homo_Sapiens.CTCF.b3        70262046
# 89         NSD2-Low-TKO.GSE131651.Homo_Sapiens.CTCF.b1        50898418
# 90         NSD2-Low-TKO.GSE131651.Homo_Sapiens.CTCF.b2        74745626
# 91         NSD2-Low-TKO.GSE131651.Homo_Sapiens.CTCF.b3        60877532
# 92             SW480.GSE136629.Homo_Sapiens.H3K27ac.b1        85846202
# 93            HCT116.GSE136629.Homo_Sapiens.H3K27ac.b1        60947468
# 94             SW620.GSE136629.Homo_Sapiens.H3K27ac.b1        56429464
# 95    HeLa-S3-shcontrol.GSE137849.Homo_Sapiens.CTCF.b1        92597092
# 96    HeLa-S3-shBHLHE40.GSE137849.Homo_Sapiens.CTCF.b1       104899432
# 97    HeLa-S3-shcontrol.GSE137849.Homo_Sapiens.CTCF.b2        78793850
# 98    HeLa-S3-shBHLHE40.GSE137849.Homo_Sapiens.CTCF.b2        55421810
# 99   THP-1-Vector-Batch1.GSE149420.Homo_Sapiens.H3K...        40776168
# 100  THP-1-Vector-Batch1.GSE149420.Homo_Sapiens.H3K...        40776168
# 101  THP-1-Vector-Batch1.GSE149420.Homo_Sapiens.H3K...        40776168
# 102  THP-1-Vector-Batch1.GSE149420.Homo_Sapiens.H3K...        40776168
# 103  THP-1-Vector-Batch2.GSE149420.Homo_Sapiens.H3K...        40776168
# 104  THP-1-Vector-Batch2.GSE149420.Homo_Sapiens.H3K...        40776168
# 105  THP-1-Vector-Batch2.GSE149420.Homo_Sapiens.H3K...        40776168
# 106  THP-1-Vector-Batch2.GSE149420.Homo_Sapiens.H3K...        40776168
# 107  THP-1-WT-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b1        44263472
# 108  THP-1-WT-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b2        44263472
# 109  THP-1-WT-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b3        44263472
# 110  THP-1-WT-Batch1.GSE149420.Homo_Sapiens.H3K4me3.b4        44263472
# 111  THP-1-WT-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b1        44263472
# 112  THP-1-WT-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b2        44263472
# 113  THP-1-WT-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b3        44263472
# 114  THP-1-WT-Batch2.GSE149420.Homo_Sapiens.H3K4me3.b4        44263472
# 115  THP-1-del-cIDR-Batch1.GSE149420.Homo_Sapiens.H...        41154856
# 116  THP-1-del-cIDR-Batch1.GSE149420.Homo_Sapiens.H...        41154856
# 117  THP-1-del-cIDR-Batch1.GSE149420.Homo_Sapiens.H...        41154856
# 118  THP-1-del-cIDR-Batch1.GSE149420.Homo_Sapiens.H...        41154856
# 119  THP-1-del-cIDR-Batch2.GSE149420.Homo_Sapiens.H...        41154856
# 120  THP-1-del-cIDR-Batch2.GSE149420.Homo_Sapiens.H...        41154856
# 121  THP-1-del-cIDR-Batch2.GSE149420.Homo_Sapiens.H...        41154856
# 122  THP-1-del-cIDR-Batch2.GSE149420.Homo_Sapiens.H...        41154856
# 123     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b1        60773444
# 124     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b2        60773444
# 125     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b3        60773444
# 126     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b4        60773444
# 127     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b5        60773444
# 128     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b6        60773444
# 129     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b7        60773444
# 130     THP-1-Vector.GSE149420.Homo_Sapiens.H3K27ac.b8        60773444
# 131         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b1        50270562
# 132         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b2        50270562
# 133         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b3        50270562
# 134         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b4        50270562
# 135         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b5        50270562
# 136         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b6        50270562
# 137         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b7        50270562
# 138         THP-1-WT.GSE149420.Homo_Sapiens.H3K27ac.b8        50270562
# 139   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b1        56929938
# 140   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b2        56929938
# 141   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b3        56929938
# 142   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b4        56929938
# 143   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b5        56929938
# 144   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b6        56929938
# 145   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b7        56929938
# 146   THP-1-del-cIDR.GSE149420.Homo_Sapiens.H3K27ac.b8        56929938
# 147            H2171.GSE151001.Homo_Sapiens.H3K27ac.b1        32217538
# 148             H524.GSE151001.Homo_Sapiens.H3K27ac.b1        33833712
# 149              H69.GSE151001.Homo_Sapiens.H3K27ac.b1        24306322
# 150       Aortic-VIC.GSE154513.Homo_Sapiens.H3K27ac.b1        56980102
# 151  A673-siCT-Dh1-72h-D347-D362.GSE156650.Homo_Sap...        89841390
# 152  A673-siSA2-Dh6-72h-D347-D362.GSE156650.Homo_Sa...        87310540
# 153  A673-siSA2-Dh8-72h-D347-D362.GSE156650.Homo_Sa...        87844764
# 154         VCAP-Veh.GSE157107.Homo_Sapiens.H3K27ac.b1        88197648
# 155     VCAP-DHT-2hr.GSE157107.Homo_Sapiens.H3K27ac.b1        96257514
# 156    VCAP-DHT-24hr.GSE157107.Homo_Sapiens.H3K27ac.b1        78880532
# 157  MDA-MB-453-DMSO.GSE157381.Homo_Sapiens.H3K27ac.b1        66973756
# 158  MDA-MB-453-Abemaciclib.GSE157381.Homo_Sapiens....        72321348
# 159        MCF7-DMSO.GSE157381.Homo_Sapiens.H3K27ac.b1        64829826
# 160  MCF7-Abemaciclib.GSE157381.Homo_Sapiens.H3K27a...        73562252
# 161       COLO320-DM.GSE159985.Homo_Sapiens.H3K27ac.b1        78743278
# 162       COLO320-DM.GSE159985.Homo_Sapiens.H3K27ac.b2        82614958
# 163            SNU16.GSE159985.Homo_Sapiens.H3K27ac.b1        60274710
# 164            SNU16.GSE159985.Homo_Sapiens.H3K27ac.b2        55976434
# 165  CD34+-Cord-Blood.GSE165207.Homo_Sapiens.H3K27a...        20990246
# 166  MB157-pInd20EBF1-10dox.GSE173843.Homo_Sapiens....       107456950
# 167  MB157-pInd20EBF1-10dox.GSE173843.Homo_Sapiens....        93101206
# 168  MB157-pInd20TCF1-10dox.GSE173843.Homo_Sapiens....        77993956
# 169  MB157-pInd20TCF1-10dox.GSE173843.Homo_Sapiens....        56318252
# 170               T47D-T0.GSE179666.Homo_Sapiens.PR.b1       129965930
# 171               T47D-T0.GSE179666.Homo_Sapiens.PR.b2       259875096
# 172          DTC1-WT.GSE180194.Homo_Sapiens.H3K27ac.b1        49342100
# 173          DTC1-WT.GSE180194.Homo_Sapiens.H3K27ac.b2        50888550
# 174        SUCCS1-WT.GSE180194.Homo_Sapiens.H3K27ac.b1        21418160
# 175        SUCCS1-WT.GSE180194.Homo_Sapiens.H3K27ac.b2        37282116
# 176      SUCCS1-siEA.GSE180194.Homo_Sapiens.H3K27ac.b1        45813034
# 177      SUCCS1-siEA.GSE180194.Homo_Sapiens.H3K27ac.b2        83074382
# 178  MDA-MB-231-sgRNA-Ctrl.GSE97585.Homo_Sapiens.H3...        34263168
# 179  MDA-MB-231-sgRNA-Ctrl.GSE97585.Homo_Sapiens.H3...        44814942
# 180  MDA-MB-231-PVT1sgRNAR3.GSE97585.Homo_Sapiens.H...        36676656
# 181  MDA-MB-231-PVT1sgRNAR3.GSE97585.Homo_Sapiens.H...        34203984
# 182  MDA-MB-231-PVT1sgRNAR2.GSE97585.Homo_Sapiens.H...        37497466
# 183  MDA-MB-231-PVT1sgRNAR2.GSE97585.Homo_Sapiens.H...        39810090
# 184                Jurkat.GSE99519.Homo_Sapiens.YY1.b1       115437388
# 185          KYSE140.GSE166232.Homo_Sapiens.H3K27ac.b1        45122342
# 186  KYSE140_ARV2hrs.GSE166232.Homo_Sapiens.H3K27ac.b1        38005506
# 187  KYSE140_ARV2hrs.GSE166232.Homo_Sapiens.H3K27ac.b2        38782830
# 188  KYSE140_DMSO2hrs.GSE166232.Homo_Sapiens.H3K27a...        35628816
# 189  KYSE140_DMSO2hrs.GSE166232.Homo_Sapiens.H3K27a...        38678790
# 190             NF_1.GSE165303.Homo_Sapiens.H3K27ac.b1        82476328
# 191             NF_2.GSE165303.Homo_Sapiens.H3K27ac.b1        83728362
# 192             NF_3.GSE165303.Homo_Sapiens.H3K27ac.b1        75658516
# 193             NF_4.GSE165303.Homo_Sapiens.H3K27ac.b1        64698450
# 194             NF_5.GSE165303.Homo_Sapiens.H3K27ac.b1        88694956
# 195             NF_6.GSE165303.Homo_Sapiens.H3K27ac.b1        86914590
# 196             NF_7.GSE165303.Homo_Sapiens.H3K27ac.b1        68952932
# 197             NF_8.GSE165303.Homo_Sapiens.H3K27ac.b1        85459592
# 198             NF_9.GSE165303.Homo_Sapiens.H3K27ac.b1        69226212
# 199            NF_10.GSE165303.Homo_Sapiens.H3K27ac.b1        90772356
# 200            DCM_1.GSE165303.Homo_Sapiens.H3K27ac.b1        60425092
# 201            DCM_2.GSE165303.Homo_Sapiens.H3K27ac.b1        88089796
# 202            DCM_3.GSE165303.Homo_Sapiens.H3K27ac.b1        72587722
# 203            DCM_4.GSE165303.Homo_Sapiens.H3K27ac.b1        75488366
# 204            DCM_5.GSE165303.Homo_Sapiens.H3K27ac.b1        72119808
# 205            DCM_6.GSE165303.Homo_Sapiens.H3K27ac.b1        74778184
# 206            DCM_7.GSE165303.Homo_Sapiens.H3K27ac.b1        86918076
# 207            DCM_8.GSE165303.Homo_Sapiens.H3K27ac.b1        80195722
# 208            DCM_9.GSE165303.Homo_Sapiens.H3K27ac.b1        76568078
# 209           DCM_10.GSE165303.Homo_Sapiens.H3K27ac.b1        71389268
# 210         hCM-Ctrl.GSE165303.Homo_Sapiens.H3K27ac.b1        79442424
# 211         hCM-Ctrl.GSE165303.Homo_Sapiens.H3K27ac.b2        67280938
# 212      hCM-HAND1OE.GSE165303.Homo_Sapiens.H3K27ac.b1        63004598
# 213      hCM-HAND1OE.GSE165303.Homo_Sapiens.H3K27ac.b2        69324714
# 214  CD4N_merged_donors_hg38.phs001703v3p1.Homo_Sap...             N/A
# 215  CD8N_merged_donors_hg38.phs001703v3p1.Homo_Sap...             N/A
# 216  Mono_merged_donors_hg38.phs001703v3p1.Homo_Sap...             N/A
# 217  NB_merged_donors_hg38.phs001703v3p1.Homo_Sapie...             N/A
# 218  NK_merged_donors_hg38.phs001703v3p1.Homo_Sapie...             N/A
# 219  NCM_merged_donors_hg38.phs001703v4p1.Homo_Sapi...             N/A
#
#                                 Control Used?  \
# 2    control present and used in peak calling
# 3    control present and used in peak calling
# 4                  no control for this sample
# 5                  no control for this sample
# 6                  no control for this sample
# 7                  no control for this sample
# 8    control present and used in peak calling
# 9    control present and used in peak calling
# 10   control present and used in peak calling
# 11   control present and used in peak calling
# 12   control present and used in peak calling
# 13   control present and used in peak calling
# 14                 no control for this sample
# 15                 no control for this sample
# 16   control present and used in peak calling
# 17   control present and used in peak calling
# 18   control present and used in peak calling
# 19   control present and used in peak calling
# 20                 no control for this sample
# 21                 no control for this sample
# 22                 no control for this sample
# 23                 no control for this sample
# 24   control present and used in peak calling
# 25   control present and used in peak calling
# 26   control present and used in peak calling
# 27   control present and used in peak calling
# 28   control present and used in peak calling
# 29                 no control for this sample
# 30                 no control for this sample
# 31   control present and used in peak calling
# 32   control present and used in peak calling
# 33   control present and used in peak calling
# 34   control present and used in peak calling
# 35   control present and used in peak calling
# 36   control present and used in peak calling
# 37   control present and used in peak calling
# 38   control present and used in peak calling
# 39   control present and used in peak calling
# 40   control present and used in peak calling
# 41   control present and used in peak calling
# 42   control present and used in peak calling
# 43   control present and used in peak calling
# 44   control present and used in peak calling
# 45   control present and used in peak calling
# 46   control present and used in peak calling
# 47                 no control for this sample
# 48                 no control for this sample
# 49                 no control for this sample
# 50                 no control for this sample
# 51                 no control for this sample
# 52                 no control for this sample
# 53                 no control for this sample
# 54                 no control for this sample
# 55                 no control for this sample
# 56                 no control for this sample
# 57                 no control for this sample
# 58                 no control for this sample
# 59                 no control for this sample
# 60                 no control for this sample
# 61   control present and used in peak calling
# 62   control present and used in peak calling
# 63   control present and used in peak calling
# 64   control present and used in peak calling
# 65   control present and used in peak calling
# 66   control present and used in peak calling
# 67   control present and used in peak calling
# 68   control present and used in peak calling
# 69   control present and used in peak calling
# 70   control present and used in peak calling
# 71   control present and used in peak calling
# 72   control present and used in peak calling
# 73   control present and used in peak calling
# 74   control present and used in peak calling
# 75   control present and used in peak calling
# 76   control present and used in peak calling
# 77   control present and used in peak calling
# 78   control present and used in peak calling
# 79   control present and used in peak calling
# 80   control present and used in peak calling
# 81   control present and used in peak calling
# 82   control present and used in peak calling
# 83                 no control for this sample
# 84   control present and used in peak calling
# 85   control present and used in peak calling
# 86                 no control for this sample
# 87                 no control for this sample
# 88                 no control for this sample
# 89                 no control for this sample
# 90                 no control for this sample
# 91                 no control for this sample
# 92   control present and used in peak calling
# 93   control present and used in peak calling
# 94   control present and used in peak calling
# 95   control present and used in peak calling
# 96   control present and used in peak calling
# 97   control present and used in peak calling
# 98   control present and used in peak calling
# 99                 no control for this sample
# 100                no control for this sample
# 101                no control for this sample
# 102                no control for this sample
# 103                no control for this sample
# 104                no control for this sample
# 105                no control for this sample
# 106                no control for this sample
# 107                no control for this sample
# 108                no control for this sample
# 109                no control for this sample
# 110                no control for this sample
# 111                no control for this sample
# 112                no control for this sample
# 113                no control for this sample
# 114                no control for this sample
# 115                no control for this sample
# 116                no control for this sample
# 117                no control for this sample
# 118                no control for this sample
# 119                no control for this sample
# 120                no control for this sample
# 121                no control for this sample
# 122                no control for this sample
# 123                no control for this sample
# 124                no control for this sample
# 125                no control for this sample
# 126                no control for this sample
# 127                no control for this sample
# 128                no control for this sample
# 129                no control for this sample
# 130                no control for this sample
# 131                no control for this sample
# 132                no control for this sample
# 133                no control for this sample
# 134                no control for this sample
# 135                no control for this sample
# 136                no control for this sample
# 137                no control for this sample
# 138                no control for this sample
# 139                no control for this sample
# 140                no control for this sample
# 141                no control for this sample
# 142                no control for this sample
# 143                no control for this sample
# 144                no control for this sample
# 145                no control for this sample
# 146                no control for this sample
# 147  control present and used in peak calling
# 148  control present and used in peak calling
# 149  control present and used in peak calling
# 150  control present and used in peak calling
# 151                no control for this sample
# 152                no control for this sample
# 153                no control for this sample
# 154                no control for this sample
# 155                no control for this sample
# 156                no control for this sample
# 157                no control for this sample
# 158                no control for this sample
# 159                no control for this sample
# 160                no control for this sample
# 161  control present and used in peak calling
# 162  control present and used in peak calling
# 163  control present and used in peak calling
# 164  control present and used in peak calling
# 165  control present and used in peak calling
# 166                no control for this sample
# 167                no control for this sample
# 168                no control for this sample
# 169                no control for this sample
# 170                no control for this sample
# 171                no control for this sample
# 172  control present and used in peak calling
# 173  control present and used in peak calling
# 174  control present and used in peak calling
# 175  control present and used in peak calling
# 176                no control for this sample
# 177                no control for this sample
# 178  control present and used in peak calling
# 179  control present and used in peak calling
# 180  control present and used in peak calling
# 181  control present and used in peak calling
# 182  control present and used in peak calling
# 183  control present and used in peak calling
# 184  control present and used in peak calling
# 185                no control for this sample
# 186                no control for this sample
# 187                no control for this sample
# 188                no control for this sample
# 189                no control for this sample
# 190                no control for this sample
# 191                no control for this sample
# 192                no control for this sample
# 193                no control for this sample
# 194                no control for this sample
# 195                no control for this sample
# 196                no control for this sample
# 197                no control for this sample
# 198                no control for this sample
# 199                no control for this sample
# 200                no control for this sample
# 201                no control for this sample
# 202                no control for this sample
# 203                no control for this sample
# 204                no control for this sample
# 205                no control for this sample
# 206                no control for this sample
# 207                no control for this sample
# 208                no control for this sample
# 209                no control for this sample
# 210                no control for this sample
# 211                no control for this sample
# 212                no control for this sample
# 213                no control for this sample
# 214                no control for this sample
# 215                no control for this sample
# 216                no control for this sample
# 217                no control for this sample
# 218                no control for this sample
# 219                no control for this sample
#
#     Narrow peaks with Q-value threshold of 0.05  \
# 2                                        152539
# 3                                         50066
# 4                                        180440
# 5                                        207431
# 6                                        241450
# 7                                        231510
# 8                                         70057
# 9                                         78363
# 10                                       208020
# 11                                       216409
# 12                                       226144
# 13                                       587075
# 14                                       193033
# 15                                       184922
# 16                                       145724
# 17                                       151849
# 18                                       175052
# 19                                       212838
# 20                                        14481
# 21                                        27460
# 22                                        19947
# 23                                        16447
# 24                                        66735
# 25                                        73400
# 26                                        19161
# 27                                        34387
# 28                                        16938
# 29                                       256560
# 30                                       196265
# 31                                        71689
# 32                                        91552
# 33                                        76280
# 34                                        68199
