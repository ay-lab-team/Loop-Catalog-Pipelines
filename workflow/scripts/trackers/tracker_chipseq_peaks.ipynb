# %%
import pandas as pd
import csv
import string
import glob
import os

# %%
# how many reads
# whether there was a control or not and whether it is used in peak calling
# how many peaks at what setting and threshold

# %%
def generate_summary_df(path):
    samples = []
    with open(path,'r') as file:

        #reader = csv.reader(file, delimiter='\t')
        #next(reader, None)
        reader = csv.DictReader(file, delimiter='\t')
        for line in reader:
            sample_info = []
            
            # if there is no sample name, skip this line
            if not line['Sample Name']:
                continue

            ##### CONSTRUCT THE SAMPLE NAME ######

            name = line['Sample Name']
            gse = line['GSE ID of Corresponding HiChIP Data']

            organism = line['Organism']
            organism = string.capwords(organism).replace(" ", "_")

            target_of_antibody = line['ChIP-seq Pull Down']
            if (target_of_antibody=="N/A"):
                continue
            
            replicate = line['Replicate Serial No']

            sample_name = name + "." + gse + "." + organism + "." + target_of_antibody + ".b" + replicate

            ###########

            # determine whether a control is present
            control_info = "no control for this sample"
            if line['Control GSM(s)']!="N/A":
                control_info = "control present and used in peak calling"

            
            # determine peak sizes and settings
            narrowpeak1 = "peak calling not completed"
            narrowpeak2 = "peak calling not completed"

            idrpeak1 = "peak calling not completed"
            idrpeak2 = "peak calling not completed"

            # check for merged replicates number of peaks
            if line['Merged replicates (if there are replicates)']=="1":
                print(sample_name)
                merged_sample_name = sample_name[:-1] + "1"
                idrpeakpath = "../../../results/peaks/merged_chipline/" + merged_sample_name
                idrpeakpath1 = idrpeakpath + "/FINAL_IDR_Peaks_FDR0.1.txt"
                idrpeakpath2 = idrpeakpath + "/FINAL_IDR_Peaks_FDR0.05.txt"

                if os.path.exists(idrpeakpath):
                    idrpeak1 = sum(1 for line in open(idrpeakpath1))
                    idrpeak2 = sum(1 for line in open(idrpeakpath2))
                else:
                    idrpeak1 = "N/A"
                    idrpeak2 = "N/A"
            
            # check for peaks per replicate
            if line['Ran peak calling']=="1":
                narrowpeakpath = "../../../results/peaks/chipline/" + sample_name + "/MACS2_Ext*/"
                narrowpeakpath1 = narrowpeakpath + sample_name + ".macs2_peaks.narrowPeak_Q0.05filt"
                narrowpeakpath2 = narrowpeakpath + sample_name + ".macs2_peaks.narrowPeak_Q0.01filt"

                if len(glob.glob(narrowpeakpath1))==1:
                    narrowpeak1 = sum(1 for line in open(glob.glob(narrowpeakpath1)[0]))
                else:
                    narrowpeak1 = "error in peak calling"

                
                if len(glob.glob(narrowpeakpath2))==1:
                    narrowpeak2 = sum(1 for line in open(glob.glob(narrowpeakpath2)[0]))
                else:
                    narrowpeak2 = "error in peak calling"


            sample_info = [sample_name, control_info, narrowpeak1, narrowpeak2, idrpeak1, idrpeak2]
            samples.append(sample_info)
    
    df = pd.DataFrame(samples)
    return df

# %%
human_path = "../../../results/samplesheets/fastq/chipseq_human_tracker.tsv"
mouse_path = "../../../results/samplesheets/fastq/chipseq_mouse_tracker.tsv"

table = []
mouse_df = generate_summary_df(mouse_path)
#human_df = generate_summary_df(human_path)

df = pd.concat([mouse_df])

columns = ["Sample Name", "Control Used?", "Narrow peaks setting 1", "Narrow peaks setting 2", "Merged peaks setting 1", "Merged peaks setting 2"]
df.columns = columns

# reset the row count
df = df.reset_index(drop=True)
df.index += 2

display(df)

# samples = pd.concat([human_samples, mouse_samples])
# samples = samples.dropna(how='all', subset=['Sample Name'])
# samples = samples.reset_index(drop=True)

# display(samples)

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(samples)
# Out:
# EryP.GSE112717.Mus_Musculus.Gata1.b1
# EryD.GSE112717.Mus_Musculus.Gata1.b1
# AML12_shCtrl.GSE141113.Mus_Musculus.H3K9me3.b1
# AML12_shCtrl.GSE141113.Mus_Musculus.H3K9me3.b2
# AML12_shSafb.GSE141113.Mus_Musculus.H3K9me3.b1
# AML12_shSafb.GSE141113.Mus_Musculus.H3K9me3.b2
# MLL-AF9.GSE110898.Mus_Musculus.H3K27ac.b1
# MLL-AF9-LSD1i.GSE110898.Mus_Musculus.H3K27ac.b1
# BL6_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1
# BL6_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2
# BL6_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b1
# BL6_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b2
# F1_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1
# F1_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2
# NOD_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1
# NOD_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2
# NOD_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b1
# NOD_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b2
# Erythroid_0hr.GSE142004.Mus_Musculus.YY1.b1
# Erythroid_0hr.GSE142004.Mus_Musculus.YY1.b2
# Erythroid_1hr.GSE142004.Mus_Musculus.YY1.b1
# Erythroid_1hr.GSE142004.Mus_Musculus.YY1.b2
# BMDM_24hIL4.GSE159629.Mus_Musculus.H3K4me3.b1
# BMDM_24hIL4.GSE159629.Mus_Musculus.H3K4me3.b2
# BMDM_Basal.GSE159629.Mus_Musculus.H3K4me3.b1
# BMDM_Basal.GSE159629.Mus_Musculus.H3K4me3.b2
# 3T3_Norm.GSE178344.Mus_Musculus.SMC1A.b1
# 3T3_TCF1.GSE178344.Mus_Musculus.SMC1A.b1
#                                         Sample Name  \
# 2              EryP.GSE112717.Mus_Musculus.Gata1.b1
# 3              EryD.GSE112717.Mus_Musculus.Gata1.b1
# 4    AML12_shCtrl.GSE141113.Mus_Musculus.H3K9me3.b1
# 5    AML12_shCtrl.GSE141113.Mus_Musculus.H3K9me3.b2
# 6    AML12_shSafb.GSE141113.Mus_Musculus.H3K9me3.b1
# 7    AML12_shSafb.GSE141113.Mus_Musculus.H3K9me3.b2
# 8         MLL-AF9.GSE110898.Mus_Musculus.H3K27ac.b1
# 9   MLL-AF9-LSD1i.GSE110898.Mus_Musculus.H3K27ac.b1
# 10      BL6_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1
# 11      BL6_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2
# 12    BL6_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b1
# 13    BL6_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b2
# 14       F1_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1
# 15       F1_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2
# 16      NOD_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b1
# 17      NOD_CD4_CD8.GSE141847.Mus_Musculus.SMC1A.b2
# 18    NOD_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b1
# 19    NOD_CD4_CD8.GSE141847.Mus_Musculus.H3K27ac.b2
# 20      Erythroid_0hr.GSE142004.Mus_Musculus.YY1.b1
# 21      Erythroid_0hr.GSE142004.Mus_Musculus.YY1.b2
# 22      Erythroid_1hr.GSE142004.Mus_Musculus.YY1.b1
# 23      Erythroid_1hr.GSE142004.Mus_Musculus.YY1.b2
# 24           mESC_WT.GSE147919.Mus_Musculus.RYBP.b1
# 25    BMDM_24hIL4.GSE159629.Mus_Musculus.H3K4me3.b1
# 26    BMDM_24hIL4.GSE159629.Mus_Musculus.H3K4me3.b2
# 27     BMDM_Basal.GSE159629.Mus_Musculus.H3K4me3.b1
# 28     BMDM_Basal.GSE159629.Mus_Musculus.H3K4me3.b2
# 29         3T3_Norm.GSE178344.Mus_Musculus.SMC1A.b1
# 30         3T3_TCF1.GSE178344.Mus_Musculus.SMC1A.b1
#
#                                Control Used?      Narrow peaks setting 1  \
# 2   control present and used in peak calling                      152539
# 3   control present and used in peak calling                       50066
# 4                 no control for this sample                      180440
# 5                 no control for this sample                      207431
# 6                 no control for this sample                      241450
# 7                 no control for this sample                      231510
# 8   control present and used in peak calling                       70057
# 9   control present and used in peak calling                       78363
# 10  control present and used in peak calling                      208020
# 11  control present and used in peak calling                      216409
# 12  control present and used in peak calling                      226144
# 13  control present and used in peak calling                      587075
# 14                no control for this sample                      193033
# 15                no control for this sample                      184922
# 16  control present and used in peak calling                      145724
# 17  control present and used in peak calling                      151849
# 18  control present and used in peak calling                      175052
# 19  control present and used in peak calling                      212838
# 20                no control for this sample                       14481
# 21                no control for this sample                       27460
# 22                no control for this sample                       19947
# 23                no control for this sample                       16447
# 24  control present and used in peak calling  peak calling not completed
# 25  control present and used in peak calling                       73400
# 26  control present and used in peak calling                       19161
# 27  control present and used in peak calling                       34387
# 28  control present and used in peak calling                       16938
# 29                no control for this sample                      256560
# 30                no control for this sample                      196265
#
#         Narrow peaks setting 2      Merged peaks setting 1  \
# 2                       146931                         N/A
# 3                        48138                         N/A
# 4                       180440                       23118
# 5                       203757                       23118
# 6                       238302                       24860
# 7                       227081                       24860
# 8                        69260                         N/A
# 9                        77423                         N/A
# 10                      208016                       60190
# 11                      216405                       60190
# 12                      219093                        8550
# 13                      587075                        8550
# 14                      193030                       54176
# 15                      184922                       54176
# 16                      145723                       49146
# 17                      151846                       49146
# 18                      175047                       28268
# 19                      212824                       28268
# 20                        1952                         501
# 21                        6980                         501
# 22                       19947                        2424
# 23                       16447                        2424
# 24  peak calling not completed  peak calling not completed
# 25                       61927                       10758
# 26                       16438                       10758
# 27                       33080                        8585
# 28                       14960                        8585
# 29                      256560                         N/A
# 30                      196265                         N/A
#
#         Merged peaks setting 2
# 2                          N/A
# 3                          N/A
# 4                        18701
# 5                        18701
# 6                        19835
# 7                        19835
# 8                          N/A
# 9                          N/A
# 10                       54901
# 11                       54901
# 12                        6131
# 13                        6131
# 14                       49544
# 15                       49544
# 16                       44951
# 17                       44951
# 18                       25429
# 19                       25429
# 20                         362
# 21                         362
# 22                        1912
# 23                        1912
# 24  peak calling not completed
# 25                        9735
# 26                        9735
# 27                        7359
# 28                        7359
# 29                         N/A
# 30                         N/A
